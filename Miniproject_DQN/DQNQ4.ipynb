# %%
# implement the dqn for me using pytorch and openai gym
import matplotlib.pyplot as plt
from gym import spaces
import json
"""Environment imports"""
from epidemic_env.env       import Env, Log
from epidemic_env.dynamics  import ModelDynamics, Observation
from epidemic_env.visualize import Visualize
from epidemic_env.agent     import Agent

"""Pytorch and numpy imports"""
import numpy as np
import torch
from torch import nn

# %matplotlib inline
dyn = ModelDynamics('config/switzerland.yaml')   # load the switzerland map

# get the cuda
# import optimimzer
import torch.optim as optim
import torch.nn.functional as F
import random
import math
from collections import namedtuple
from itertools import count
from IPython import display
from torch.autograd import Variable
from collections import deque
import time

# %%
class DQN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQN, self).__init__()
        self.linear1 = nn.Linear(input_dim, 64)
        self.linear2 = nn.Linear(64, 32)
        self.linear3 = nn.Linear(32, 16)
        self.linear4 = nn.Linear(16, output_dim)
        
    def forward(self, x):
        x = x.view(-1, input_dim)
        x = torch.relu(self.linear1(x))
        x = torch.relu(self.linear2(x)) 
        x = torch.relu(self.linear3(x))
        return self.linear4(x)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device}")
def int_to_tensor(x):
    return torch.tensor(x, dtype=torch.float32, device=device).unsqueeze(0)
# Out:
# Using cuda

# %%
action_space        =   spaces.Discrete(5)
observation_space   =   spaces.Box( low=0,
                                    high=1,
                                    shape=(2, dyn.n_cities, dyn.env_step_length),
                                    dtype=np.float16)
print(f"sampled action : {action_space.sample()}")
print("Sampled observation")
plt.matshow(observation_space.sample()[1,:,:])
plt.show()

SCALE = 100
ACTION_NULL = 0
ACTION_CONFINE = 1
ACTION_ISOLATE = 2
ACTION_HOSPITAL = 3
ACTION_VACCINATE = 4
def action_preprocessor_m(a:torch.Tensor, dyn:ModelDynamics):
    action = { # DO NOTHING
        'confinement': False, 
        'isolation': False, 
        'hospital': False, 
        'vaccinate': False,
    }
    
    if a == ACTION_CONFINE:
        action['confinement'] = bool( 1 - dyn.get_action()['confinement'] ) 
    elif a == ACTION_ISOLATE:
        action['isolation'] = bool( 1 - dyn.get_action()['isolation'] )
    elif a == ACTION_VACCINATE:
        action['vaccinate'] = bool( 1 - dyn.get_action()['vaccinate'] )
    elif a == ACTION_HOSPITAL:
        action['hospital'] = bool( 1 - dyn.get_action()['hospital'] )
        
    return action

def observation_preprocessor_m(obs: Observation, dyn:ModelDynamics):
    infected = SCALE * np.power(np.array([np.array(obs.city[c].infected)/obs.pop[c] for c in dyn.cities]), 0.25)
    dead = SCALE * np.power( np.array([np.array(obs.city[c].dead)/obs.pop[c] for c in dyn.cities]), 0.25)
    confined = np.ones_like(dead)*int((dyn.get_action()['confinement']))
    isolationed = np.ones_like(dead)*int((dyn.get_action()['isolation']))
    hospitaled = np.ones_like(dead)*int((dyn.get_action()['hospital']))
    vaccinated = np.ones_like(dead)*int((dyn.get_action()['vaccinate']))

    return torch.Tensor(np.stack((infected, dead, confined, isolationed, hospitaled, vaccinated))).unsqueeze(0)
# Out:
# sampled action : 0
# Sampled observation

# %%
env_m = Env(  dyn,
            action_space=action_space,
            observation_space=observation_space,
            action_preprocessor=action_preprocessor_m,
            observation_preprocessor=observation_preprocessor_m,
            )

# %%
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward')) # define the transition tuple

class DQN_Agent(Agent):
    def __init__(self,  env:Env, epsilon:float = 0.7, batch_size: int = 2048, buffer_size: int = 20000, device = 'cuda', GAMMA : float = 0.9,
                 lr : float = 1e-5, policy_net = None, target_net = None, optimizer = None,
                # Additionnal parameters to be added here
                ):
        self.epsilon = epsilon
        self.env = env
        self.batch_size = batch_size
        self.buffer_size = buffer_size
        self.memory_initial()
        self.device = device
        self.GAMMA = GAMMA
        self.lr = lr
        self.policy_net = policy_net
        self.target_net = target_net
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.lr)

    def save_model(self, savepath):
        # This is where one would define the routine for loading a pre-trained model
        torch.save(self.policy_net.state_dict(), savepath)
        pass

    def load_model(self, savepath):
        # This is where one would define the routine for saving the weights for a trained model
        self.policy_net.load_state_dict(torch.load(savepath))
        self.target_net.load_state_dict(self.policy_net.state_dict())
        pass

    def reset(self,):
        # This should be called when the environment is reset
        pass
    
    # the action function for Q3a
    def act(self, obs, temp_epsilon):
        # write the epsilon-greedy policy here
        if random.random() < temp_epsilon:
            return int_to_tensor( self.env.action_space.sample()).unsqueeze(0) 
        else:
            m = self.policy_net(obs.to(self.device)).max(1)[1].view(1, 1)
            return m # return the action with the highest q-value
    
    # the action functio for Q3b
    def act_decay(self, obs, epsilon0, epsilonmin, Tmax, t):
        temp_epsilon = np.max([epsilon0*(Tmax-t)/Tmax, epsilonmin])
        return self.act(obs, temp_epsilon)
        
    def memory_initial(self):
        # initialize the memory
        self.memory = deque([],maxlen= self.buffer_size) # define the memory as a deque of size capacity

    def memory_push(self, transition):
        # push a transition into the memory
        self.memory.append(transition)

    def memory_sample(self):
        # sample a batch from memory
        return random.sample(self.memory, self.batch_size)
    
    def memory_len(self):
        # return the length of the memory
        return len(self.memory)
    
    def optimize_model(self, train = True):
        # This is where one would define the optimization step of an RL algorithm
        if self.memory_len() < self.batch_size:
            return 0
        transitions = self.memory_sample()

        batch = Transition(*zip(*transitions)) # unzip the batch

        non_final_mask = torch.tensor(tuple(map(lambda s: s is not None, batch.next_state)), device= self.device, dtype=torch.bool).to(device)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None]).to(device)

        state_batch = torch.cat(batch.state).to(device)
        
        action_batch = torch.cat(batch.action).to(device)
        reward_batch = torch.cat(batch.reward).squeeze().to(device)

        action_batch = action_batch.long()
        state_action_values = self.policy_net(state_batch).gather(1, action_batch).to(device)
        next_state_values = torch.zeros(self.batch_size, device= self.device)


        with torch.no_grad():
            next_state_values[non_final_mask] = self.target_net(non_final_next_states).max(1)[0]
        # Compute the expected Q values

        expected_state_action_values = (next_state_values * self.GAMMA) + reward_batch
                
        criterion = nn.MSELoss() # define the loss function

        loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))
        
        if train == True:
            # Optimize the model
            self.optimizer.zero_grad()
            loss.backward()
            # In-place gradient clipping
            torch.nn.utils.clip_grad_value_(self.policy_net.parameters(), 100) 
            self.optimizer.step()
        return loss.item()
    
    def update_target_model(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

# %%
random_seed = 42 
BATCH_SIZE = 2048
GAMMA = 0.9
LR = 1e-5
input_dim = 6 * dyn.n_cities * dyn.env_step_length

state, info = env_m.reset(42)


# Initialize policy and target network
policy_net_m = DQN(input_dim, 5).to(device)
target_net_m = DQN(input_dim, 5).to(device)
# Initialize the target network to be the same as the policy network
target_net_m.load_state_dict(policy_net_m.state_dict()) 


DQNagent_m = DQN_Agent(env_m, epsilon=0.7, batch_size=BATCH_SIZE, buffer_size=20000, GAMMA=GAMMA,lr = LR, device=device ,
                    policy_net=policy_net_m, target_net=target_net_m)



def one_episode_decay(env,agent,random_seed, epsilon0, epsilonmin, Tmax, t):
    state, _ = env.reset(random_seed)
    done = False
    total_reward = 0
    total_loss = 0

    while not done:
        action = agent.act_decay(state, epsilon0, epsilonmin, Tmax, t)
        next_state, reward, done, _ = env.step(action)
        agent.memory_push(Transition(state, action, next_state, reward))
        state = next_state
        total_reward += reward
        loss = agent.optimize_model()
        total_loss += loss
    
    return total_reward.item(), total_loss


def eval_one(env,agent, random_seed):
    state, _ = env.reset(random_seed)
    done = False
    total_reward = 0
    total_loss = 0

    while not done:
        action = agent.act(state,0)
        next_state, reward, done, _ = env.step(action)
        state = next_state
        total_reward += reward
        loss = agent.optimize_model(train = False)
        total_loss += loss
    
    return total_reward.item(), total_loss



def train_Q4():
    train_loss_trace = []
    train_reward_trace = []
    eval_loss_trace = []
    eval_reward_trace = []

    best = -np.inf

    for i in range(1,501):
        reward, loss = one_episode_decay(env_m,DQNagent_m,i,0.7,0.2,500,i)
        train_loss_trace.append(loss)
        train_reward_trace.append(reward)
        print(f"   every episode report:      Episode {i} : reward {reward}, loss {loss}")
        if i % 5 == 0:
            DQNagent_m.update_target_model()
        if i % 50 == 0 :
            tuple_list = np.array([eval_one(env_m,DQNagent_m,i) for m in range(20)])
            eval_losss = np.mean(tuple_list,axis = 0)[1]
            eval_rewards = np.mean(tuple_list,axis = 0)[0]

            eval_loss_trace.append(eval_losss)
            eval_reward_trace.append(eval_rewards)
            train_loss = np.mean(train_loss_trace[i-50:i-1])
            train_reward = np.mean(train_reward_trace[i-50:i-1])
            
            if eval_rewards > best:
                best = eval_rewards
                torch.save(DQNagent_m.policy_net.state_dict(), "DQN_best_Q4.pth")
            print(f"Episode {i} : train_reward {train_reward}, train_loss {train_loss}")
            print(f"Episode {i} : eval_reward {eval_rewards}, eval_loss {eval_losss}")

    with open('Q4_train_loss.json', 'w') as f: json.dump(train_loss_trace, f)
    with open('Q4_train_reward.json', 'w') as f: json.dump(train_reward_trace, f)
    with open('Q4_eval_loss.json', 'w') as f: json.dump(eval_loss_trace, f)
    with open('Q4_eval_reward.json', 'w') as f: json.dump(eval_reward_trace, f)

# %%
train_Q4()
# Out:
#    every episode report:      Episode 1 : reward -183.91021728515625, loss 0
#    every episode report:      Episode 2 : reward -217.986328125, loss 0
#    every episode report:      Episode 3 : reward -238.0584716796875, loss 0
#    every episode report:      Episode 4 : reward -149.30545043945312, loss 0
#    every episode report:      Episode 5 : reward -189.85049438476562, loss 0
#    every episode report:      Episode 6 : reward -407.8316650390625, loss 0
#    every episode report:      Episode 7 : reward -228.0486602783203, loss 0
#    every episode report:      Episode 8 : reward -187.10653686523438, loss 0
#    every episode report:      Episode 9 : reward -257.21954345703125, loss 0
#    every episode report:      Episode 10 : reward -223.2552947998047, loss 0
#    every episode report:      Episode 11 : reward -251.12353515625, loss 0
#    every episode report:      Episode 12 : reward -186.4628143310547, loss 0
#    every episode report:      Episode 13 : reward -107.30941009521484, loss 0
#    every episode report:      Episode 14 : reward -274.2594299316406, loss 0
#    every episode report:      Episode 15 : reward -250.07723999023438, loss 0
#    every episode report:      Episode 16 : reward -150.22055053710938, loss 0
#    every episode report:      Episode 17 : reward -249.6868438720703, loss 0
#    every episode report:      Episode 18 : reward -225.45941162109375, loss 0
#    every episode report:      Episode 19 : reward -230.80844116210938, loss 0
#    every episode report:      Episode 20 : reward -224.78392028808594, loss 0
#    every episode report:      Episode 21 : reward -300.3463134765625, loss 0
#    every episode report:      Episode 22 : reward -209.22604370117188, loss 0
#    every episode report:      Episode 23 : reward -213.2283935546875, loss 0
#    every episode report:      Episode 24 : reward -310.4733581542969, loss 0
#    every episode report:      Episode 25 : reward -216.7711181640625, loss 0
#    every episode report:      Episode 26 : reward -133.44110107421875, loss 0
#    every episode report:      Episode 27 : reward -241.29217529296875, loss 0
#    every episode report:      Episode 28 : reward -296.5542907714844, loss 0
#    every episode report:      Episode 29 : reward -326.68536376953125, loss 0
#    every episode report:      Episode 30 : reward -269.07855224609375, loss 0
#    every episode report:      Episode 31 : reward -223.59278869628906, loss 0
#    every episode report:      Episode 32 : reward -219.3760223388672, loss 0
#    every episode report:      Episode 33 : reward -222.51211547851562, loss 0
#    every episode report:      Episode 34 : reward -236.2220916748047, loss 0
#    every episode report:      Episode 35 : reward -389.1181335449219, loss 0
#    every episode report:      Episode 36 : reward -118.3878173828125, loss 0
#    every episode report:      Episode 37 : reward -220.3336639404297, loss 0
#    every episode report:      Episode 38 : reward -222.28260803222656, loss 0
#    every episode report:      Episode 39 : reward -232.56411743164062, loss 0
#    every episode report:      Episode 40 : reward -243.66416931152344, loss 0
#    every episode report:      Episode 41 : reward -212.8000946044922, loss 0
#    every episode report:      Episode 42 : reward -234.7163848876953, loss 0
#    every episode report:      Episode 43 : reward -224.83885192871094, loss 0
#    every episode report:      Episode 44 : reward -209.34986877441406, loss 0
#    every episode report:      Episode 45 : reward -217.54547119140625, loss 0
#    every episode report:      Episode 46 : reward -234.2396240234375, loss 0
#    every episode report:      Episode 47 : reward -210.38685607910156, loss 0
#    every episode report:      Episode 48 : reward -158.0055694580078, loss 0
#    every episode report:      Episode 49 : reward -195.93067932128906, loss 0
#    every episode report:      Episode 50 : reward -305.82952880859375, loss 0
# Episode 50 : train_reward -228.07607954375598, train_loss 0.0
# Episode 50 : eval_reward -242.0854034423828, eval_loss 0.0
#    every episode report:      Episode 51 : reward -214.8184814453125, loss 0
#    every episode report:      Episode 52 : reward -256.8842468261719, loss 0
#    every episode report:      Episode 53 : reward -159.2650146484375, loss 0
#    every episode report:      Episode 54 : reward -239.03366088867188, loss 0
#    every episode report:      Episode 55 : reward -298.3736877441406, loss 0
#    every episode report:      Episode 56 : reward -246.88671875, loss 0
#    every episode report:      Episode 57 : reward -269.48602294921875, loss 0
#    every episode report:      Episode 58 : reward -242.15643310546875, loss 0
#    every episode report:      Episode 59 : reward -250.69679260253906, loss 0
#    every episode report:      Episode 60 : reward -215.82398986816406, loss 0
#    every episode report:      Episode 61 : reward -263.1438293457031, loss 0
#    every episode report:      Episode 62 : reward -201.51687622070312, loss 0
#    every episode report:      Episode 63 : reward -248.04583740234375, loss 0
#    every episode report:      Episode 64 : reward -316.437744140625, loss 0
#    every episode report:      Episode 65 : reward -264.04913330078125, loss 0
#    every episode report:      Episode 66 : reward -130.80885314941406, loss 0
#    every episode report:      Episode 67 : reward -173.02969360351562, loss 0
#    every episode report:      Episode 68 : reward -248.0862274169922, loss 0
#    every episode report:      Episode 69 : reward -321.686279296875, loss 13062.862060546875
#    every episode report:      Episode 70 : reward -211.9291534423828, loss 16924.043518066406
#    every episode report:      Episode 71 : reward -135.70346069335938, loss 16856.41815185547
#    every episode report:      Episode 72 : reward -214.62261962890625, loss 17008.043395996094
#    every episode report:      Episode 73 : reward -276.70892333984375, loss 16906.11651611328
#    every episode report:      Episode 74 : reward -238.570068359375, loss 17093.878051757812
#    every episode report:      Episode 75 : reward -149.84243774414062, loss 16795.792572021484
#    every episode report:      Episode 76 : reward -195.7322235107422, loss 17265.918823242188
#    every episode report:      Episode 77 : reward -164.59193420410156, loss 16933.516876220703
#    every episode report:      Episode 78 : reward -200.16566467285156, loss 16785.1689453125
#    every episode report:      Episode 79 : reward -152.7913360595703, loss 16846.96368408203
#    every episode report:      Episode 80 : reward -172.70584106445312, loss 16763.66128540039
#    every episode report:      Episode 81 : reward -173.41844177246094, loss 16871.01220703125
#    every episode report:      Episode 82 : reward -230.4576416015625, loss 16635.60089111328
#    every episode report:      Episode 83 : reward -174.5074920654297, loss 16433.66030883789
#    every episode report:      Episode 84 : reward -230.48085021972656, loss 16589.51724243164
#    every episode report:      Episode 85 : reward -259.68353271484375, loss 16283.0810546875
#    every episode report:      Episode 86 : reward -144.31800842285156, loss 16464.644897460938
#    every episode report:      Episode 87 : reward -197.7867889404297, loss 16166.65658569336
#    every episode report:      Episode 88 : reward -226.0590362548828, loss 16329.319732666016
#    every episode report:      Episode 89 : reward -224.81533813476562, loss 16003.381469726562
#    every episode report:      Episode 90 : reward -207.64291381835938, loss 15833.339172363281
#    every episode report:      Episode 91 : reward -211.89427185058594, loss 16561.600524902344
#    every episode report:      Episode 92 : reward -170.57272338867188, loss 16341.408386230469
#    every episode report:      Episode 93 : reward -281.734619140625, loss 16051.983276367188
#    every episode report:      Episode 94 : reward -390.3462219238281, loss 16341.088836669922
#    every episode report:      Episode 95 : reward -224.36228942871094, loss 16273.510437011719
#    every episode report:      Episode 96 : reward -227.41888427734375, loss 17121.670379638672
#    every episode report:      Episode 97 : reward -225.07315063476562, loss 16943.241943359375
#    every episode report:      Episode 98 : reward -251.67880249023438, loss 16259.37954711914
#    every episode report:      Episode 99 : reward -181.50119018554688, loss 16444.386749267578
#    every episode report:      Episode 100 : reward -231.86758422851562, loss 16325.576538085938
# Episode 100 : train_reward -222.59888536102918, train_loss 10432.466684146802
# Episode 100 : eval_reward -201.02188110351562, eval_loss 17558.27032470703
#    every episode report:      Episode 101 : reward -214.49827575683594, loss 17361.143493652344
#    every episode report:      Episode 102 : reward -306.2229309082031, loss 17473.315551757812
#    every episode report:      Episode 103 : reward -251.09384155273438, loss 17145.680541992188
#    every episode report:      Episode 104 : reward -142.8157958984375, loss 16665.593627929688
#    every episode report:      Episode 105 : reward -172.32057189941406, loss 16351.79165649414
#    every episode report:      Episode 106 : reward -228.426513671875, loss 17802.270935058594
#    every episode report:      Episode 107 : reward -186.47216796875, loss 17066.36392211914
#    every episode report:      Episode 108 : reward -280.5180969238281, loss 16679.534271240234
#    every episode report:      Episode 109 : reward -292.2547912597656, loss 16623.497131347656
#    every episode report:      Episode 110 : reward -226.15896606445312, loss 16430.39971923828
#    every episode report:      Episode 111 : reward -131.42193603515625, loss 17875.62384033203
#    every episode report:      Episode 112 : reward -124.18832397460938, loss 17020.154907226562
#    every episode report:      Episode 113 : reward -279.8862609863281, loss 16890.2099609375
#    every episode report:      Episode 114 : reward -107.52519989013672, loss 15827.553955078125
#    every episode report:      Episode 115 : reward -258.73089599609375, loss 15593.897003173828
#    every episode report:      Episode 116 : reward -267.67169189453125, loss 17841.88153076172
#    every episode report:      Episode 117 : reward -166.4038543701172, loss 16904.87969970703
#    every episode report:      Episode 118 : reward -158.82217407226562, loss 16567.461791992188
#    every episode report:      Episode 119 : reward -269.93035888671875, loss 16015.758728027344
#    every episode report:      Episode 120 : reward -146.87660217285156, loss 15880.167724609375
#    every episode report:      Episode 121 : reward -220.22677612304688, loss 18283.080078125
#    every episode report:      Episode 122 : reward -120.79908752441406, loss 16598.163696289062
#    every episode report:      Episode 123 : reward -220.83554077148438, loss 16153.65170288086
#    every episode report:      Episode 124 : reward -133.2872772216797, loss 15613.77651977539
#    every episode report:      Episode 125 : reward -234.57119750976562, loss 15543.08187866211
#    every episode report:      Episode 126 : reward -195.89830017089844, loss 17696.304138183594
#    every episode report:      Episode 127 : reward -179.25637817382812, loss 16699.009185791016
#    every episode report:      Episode 128 : reward -252.28802490234375, loss 16377.813903808594
#    every episode report:      Episode 129 : reward -110.11106872558594, loss 15463.907470703125
#    every episode report:      Episode 130 : reward -157.22174072265625, loss 15163.843994140625
#    every episode report:      Episode 131 : reward -146.4949951171875, loss 18024.54736328125
#    every episode report:      Episode 132 : reward -117.22926330566406, loss 16921.955963134766
#    every episode report:      Episode 133 : reward -176.8653106689453, loss 15917.811065673828
#    every episode report:      Episode 134 : reward -220.22544860839844, loss 15412.598663330078
#    every episode report:      Episode 135 : reward -180.64768981933594, loss 14952.056121826172
#    every episode report:      Episode 136 : reward -175.28765869140625, loss 17507.429260253906
#    every episode report:      Episode 137 : reward -201.1319580078125, loss 16726.46939086914
#    every episode report:      Episode 138 : reward -215.00393676757812, loss 15627.38003540039
#    every episode report:      Episode 139 : reward -140.62672424316406, loss 15117.184997558594
#    every episode report:      Episode 140 : reward -154.55735778808594, loss 14414.956115722656
#    every episode report:      Episode 141 : reward -205.42306518554688, loss 17423.642120361328
#    every episode report:      Episode 142 : reward -117.92086791992188, loss 15865.181030273438
#    every episode report:      Episode 143 : reward -210.4096221923828, loss 15536.530639648438
#    every episode report:      Episode 144 : reward -204.94313049316406, loss 15123.129272460938
#    every episode report:      Episode 145 : reward -184.23545837402344, loss 14581.768005371094
#    every episode report:      Episode 146 : reward -190.62965393066406, loss 16971.661895751953
#    every episode report:      Episode 147 : reward -125.95219421386719, loss 16136.274230957031
#    every episode report:      Episode 148 : reward -125.55986022949219, loss 15589.595123291016
#    every episode report:      Episode 149 : reward -237.5640869140625, loss 15054.753723144531
#    every episode report:      Episode 150 : reward -207.15463256835938, loss 14178.920654296875
# Episode 150 : train_reward -191.17230458162268, train_loss 16377.851787333586
# Episode 150 : eval_reward -205.5020751953125, eval_loss 16786.137634277344
#    every episode report:      Episode 151 : reward -179.2123565673828, loss 16608.927673339844
#    every episode report:      Episode 152 : reward -209.350830078125, loss 15736.98583984375
#    every episode report:      Episode 153 : reward -328.1134338378906, loss 15473.35400390625
#    every episode report:      Episode 154 : reward -146.47601318359375, loss 14910.938079833984
#    every episode report:      Episode 155 : reward -195.17857360839844, loss 14669.99185180664
#    every episode report:      Episode 156 : reward -144.43603515625, loss 16743.742736816406
#    every episode report:      Episode 157 : reward -273.6761169433594, loss 16216.452514648438
#    every episode report:      Episode 158 : reward -243.81243896484375, loss 15655.607543945312
#    every episode report:      Episode 159 : reward -173.5723419189453, loss 14955.797729492188
#    every episode report:      Episode 160 : reward -225.60787963867188, loss 14825.491027832031
#    every episode report:      Episode 161 : reward -185.60137939453125, loss 16340.757904052734
#    every episode report:      Episode 162 : reward -221.10031127929688, loss 15889.10043334961
#    every episode report:      Episode 163 : reward -250.78997802734375, loss 15149.975402832031
#    every episode report:      Episode 164 : reward -189.16676330566406, loss 14942.638793945312
#    every episode report:      Episode 165 : reward -196.5802001953125, loss 14658.268981933594
#    every episode report:      Episode 166 : reward -221.39727783203125, loss 16452.702911376953
#    every episode report:      Episode 167 : reward -351.40057373046875, loss 15943.816040039062
#    every episode report:      Episode 168 : reward -93.52116394042969, loss 15605.742797851562
#    every episode report:      Episode 169 : reward -216.28358459472656, loss 15292.362030029297
#    every episode report:      Episode 170 : reward -161.7420654296875, loss 14596.54574584961
#    every episode report:      Episode 171 : reward -153.85540771484375, loss 16623.38247680664
#    every episode report:      Episode 172 : reward -173.70443725585938, loss 16120.662689208984
#    every episode report:      Episode 173 : reward -169.4860076904297, loss 15513.330078125
#    every episode report:      Episode 174 : reward -61.95964813232422, loss 15517.681701660156
#    every episode report:      Episode 175 : reward -185.86354064941406, loss 15090.646942138672
#    every episode report:      Episode 176 : reward -233.82481384277344, loss 17057.663970947266
#    every episode report:      Episode 177 : reward -195.3817138671875, loss 15791.532104492188
#    every episode report:      Episode 178 : reward -256.3345642089844, loss 15780.15347290039
#    every episode report:      Episode 179 : reward -162.2290802001953, loss 15738.772338867188
#    every episode report:      Episode 180 : reward -124.95893859863281, loss 15388.423736572266
#    every episode report:      Episode 181 : reward -96.66773986816406, loss 16550.99789428711
#    every episode report:      Episode 182 : reward -93.63461303710938, loss 16017.69906616211
#    every episode report:      Episode 183 : reward -112.42369079589844, loss 15866.837524414062
#    every episode report:      Episode 184 : reward -102.072509765625, loss 15518.299713134766
#    every episode report:      Episode 185 : reward -119.66664123535156, loss 15245.583435058594
#    every episode report:      Episode 186 : reward -220.6859588623047, loss 15911.03872680664
#    every episode report:      Episode 187 : reward -189.7775115966797, loss 16005.977905273438
#    every episode report:      Episode 188 : reward -253.7528076171875, loss 15676.28207397461
#    every episode report:      Episode 189 : reward -100.1883544921875, loss 15461.523010253906
#    every episode report:      Episode 190 : reward -47.49750900268555, loss 15110.438934326172
#    every episode report:      Episode 191 : reward -168.11917114257812, loss 15842.894165039062
#    every episode report:      Episode 192 : reward -79.67027282714844, loss 15183.849243164062
#    every episode report:      Episode 193 : reward -207.79693603515625, loss 14687.771667480469
#    every episode report:      Episode 194 : reward -216.916015625, loss 15426.677154541016
#    every episode report:      Episode 195 : reward -406.12445068359375, loss 15087.024719238281
#    every episode report:      Episode 196 : reward -121.41720581054688, loss 16026.286193847656
#    every episode report:      Episode 197 : reward -158.2332000732422, loss 15176.756286621094
#    every episode report:      Episode 198 : reward -195.92529296875, loss 15308.245727539062
#    every episode report:      Episode 199 : reward -81.79638671875, loss 14838.528991699219
#    every episode report:      Episode 200 : reward -117.02369689941406, loss 15072.158477783203
# Episode 200 : train_reward -181.57109669276647, train_loss 15596.61555076132
# Episode 200 : eval_reward -63.326202392578125, eval_loss 15918.550506591797
#    every episode report:      Episode 201 : reward -126.69264221191406, loss 15208.297424316406
#    every episode report:      Episode 202 : reward -138.56849670410156, loss 15128.294219970703
#    every episode report:      Episode 203 : reward -202.69638061523438, loss 15181.833374023438
#    every episode report:      Episode 204 : reward -209.88914489746094, loss 14783.636413574219
#    every episode report:      Episode 205 : reward -56.72798538208008, loss 14470.850158691406
#    every episode report:      Episode 206 : reward -207.35133361816406, loss 15064.76742553711
#    every episode report:      Episode 207 : reward -174.66831970214844, loss 14917.483764648438
#    every episode report:      Episode 208 : reward -121.49583435058594, loss 14633.240997314453
#    every episode report:      Episode 209 : reward -228.6907196044922, loss 14878.089874267578
#    every episode report:      Episode 210 : reward -174.91558837890625, loss 14160.287414550781
#    every episode report:      Episode 211 : reward -137.78781127929688, loss 14273.811065673828
#    every episode report:      Episode 212 : reward -282.4474792480469, loss 14126.193145751953
#    every episode report:      Episode 213 : reward -127.89535522460938, loss 13973.449768066406
#    every episode report:      Episode 214 : reward -149.25759887695312, loss 13772.142822265625
#    every episode report:      Episode 215 : reward -199.2579803466797, loss 13665.833435058594
#    every episode report:      Episode 216 : reward -213.98822021484375, loss 13883.350494384766
#    every episode report:      Episode 217 : reward -122.51435852050781, loss 13943.53677368164
#    every episode report:      Episode 218 : reward -188.08847045898438, loss 13478.192016601562
#    every episode report:      Episode 219 : reward -170.3380126953125, loss 13169.436126708984
#    every episode report:      Episode 220 : reward -170.11160278320312, loss 13674.141540527344
#    every episode report:      Episode 221 : reward -222.6719970703125, loss 13204.133270263672
#    every episode report:      Episode 222 : reward -219.04336547851562, loss 13159.766387939453
#    every episode report:      Episode 223 : reward -167.1298828125, loss 13054.537200927734
#    every episode report:      Episode 224 : reward -169.50918579101562, loss 12834.804870605469
#    every episode report:      Episode 225 : reward -133.96923828125, loss 12850.926849365234
#    every episode report:      Episode 226 : reward -176.1963653564453, loss 13125.007781982422
#    every episode report:      Episode 227 : reward -147.00694274902344, loss 13050.882080078125
#    every episode report:      Episode 228 : reward -177.0186004638672, loss 12877.412322998047
#    every episode report:      Episode 229 : reward -164.48794555664062, loss 12827.13671875
#    every episode report:      Episode 230 : reward -253.8878936767578, loss 12823.613647460938
#    every episode report:      Episode 231 : reward -226.13656616210938, loss 12961.560363769531
#    every episode report:      Episode 232 : reward -201.6322021484375, loss 12771.908508300781
#    every episode report:      Episode 233 : reward -122.76753234863281, loss 12627.523651123047
#    every episode report:      Episode 234 : reward -157.47425842285156, loss 12446.433349609375
#    every episode report:      Episode 235 : reward -63.84437561035156, loss 12085.64096069336
#    every episode report:      Episode 236 : reward -176.0862274169922, loss 12231.051177978516
#    every episode report:      Episode 237 : reward -207.52133178710938, loss 12654.951202392578
#    every episode report:      Episode 238 : reward -256.96356201171875, loss 12501.840942382812
#    every episode report:      Episode 239 : reward -58.382286071777344, loss 12432.634674072266
#    every episode report:      Episode 240 : reward -79.50659942626953, loss 12064.55322265625
#    every episode report:      Episode 241 : reward -95.96173858642578, loss 12513.520904541016
#    every episode report:      Episode 242 : reward -158.11587524414062, loss 12170.595397949219
#    every episode report:      Episode 243 : reward -114.06124877929688, loss 12423.75308227539
#    every episode report:      Episode 244 : reward -168.34393310546875, loss 12015.310607910156
#    every episode report:      Episode 245 : reward -107.1273193359375, loss 11803.79183959961
#    every episode report:      Episode 246 : reward -112.51506042480469, loss 12240.179077148438
#    every episode report:      Episode 247 : reward -90.31127166748047, loss 11939.935607910156
#    every episode report:      Episode 248 : reward -170.2464141845703, loss 12151.282623291016
#    every episode report:      Episode 249 : reward -182.84420776367188, loss 12027.175476074219
#    every episode report:      Episode 250 : reward -63.41527557373047, loss 11982.649291992188
# Episode 250 : train_reward -162.94177067036532, train_loss 13270.58636848294
# Episode 250 : eval_reward -28.408226013183594, eval_loss 12196.626190185547
#    every episode report:      Episode 251 : reward -171.5396270751953, loss 12368.49478149414
#    every episode report:      Episode 252 : reward -97.5039291381836, loss 11943.44125366211
#    every episode report:      Episode 253 : reward -94.43316650390625, loss 11926.408416748047
#    every episode report:      Episode 254 : reward -50.870391845703125, loss 11934.502471923828
#    every episode report:      Episode 255 : reward -203.4624786376953, loss 11722.214813232422
#    every episode report:      Episode 256 : reward -138.4622039794922, loss 11666.439453125
#    every episode report:      Episode 257 : reward -56.281585693359375, loss 11877.738800048828
#    every episode report:      Episode 258 : reward -130.18798828125, loss 11761.112030029297
#    every episode report:      Episode 259 : reward -89.99861907958984, loss 11572.00033569336
#    every episode report:      Episode 260 : reward -201.69761657714844, loss 11257.821533203125
#    every episode report:      Episode 261 : reward -89.99962615966797, loss 11703.939025878906
#    every episode report:      Episode 262 : reward -172.53944396972656, loss 11731.975158691406
#    every episode report:      Episode 263 : reward -239.22686767578125, loss 11403.757202148438
#    every episode report:      Episode 264 : reward -125.95512390136719, loss 11364.452423095703
#    every episode report:      Episode 265 : reward -234.09783935546875, loss 11508.66537475586
#    every episode report:      Episode 266 : reward -162.97694396972656, loss 11254.42642211914
#    every episode report:      Episode 267 : reward -139.85470581054688, loss 11680.334655761719
#    every episode report:      Episode 268 : reward -252.84249877929688, loss 11125.925109863281
#    every episode report:      Episode 269 : reward -122.18701171875, loss 11466.724426269531
#    every episode report:      Episode 270 : reward -225.9671173095703, loss 10849.912475585938
#    every episode report:      Episode 271 : reward -251.86618041992188, loss 11485.756530761719
#    every episode report:      Episode 272 : reward -171.51324462890625, loss 11821.928527832031
#    every episode report:      Episode 273 : reward -100.42294311523438, loss 11427.172790527344
#    every episode report:      Episode 274 : reward -377.9958801269531, loss 11633.727600097656
#    every episode report:      Episode 275 : reward -206.24087524414062, loss 11467.565521240234
#    every episode report:      Episode 276 : reward -62.058921813964844, loss 11332.089141845703
#    every episode report:      Episode 277 : reward -143.5274658203125, loss 11690.266784667969
#    every episode report:      Episode 278 : reward -113.7422866821289, loss 11793.75390625
#    every episode report:      Episode 279 : reward -209.58648681640625, loss 11272.848236083984
#    every episode report:      Episode 280 : reward -132.1167449951172, loss 11478.190490722656
#    every episode report:      Episode 281 : reward -82.35263061523438, loss 11296.296478271484
#    every episode report:      Episode 282 : reward -158.24127197265625, loss 11229.47216796875
#    every episode report:      Episode 283 : reward -105.41120910644531, loss 11193.685729980469
#    every episode report:      Episode 284 : reward -99.5171890258789, loss 11184.721496582031
#    every episode report:      Episode 285 : reward -46.53755187988281, loss 11115.513702392578
#    every episode report:      Episode 286 : reward -296.12274169921875, loss 11114.252044677734
#    every episode report:      Episode 287 : reward -120.20114135742188, loss 11193.492797851562
#    every episode report:      Episode 288 : reward -193.2803192138672, loss 10825.244079589844
#    every episode report:      Episode 289 : reward -216.79904174804688, loss 11204.116271972656
#    every episode report:      Episode 290 : reward -133.7891845703125, loss 10980.84976196289
#    every episode report:      Episode 291 : reward -104.4788818359375, loss 11118.72640991211
#    every episode report:      Episode 292 : reward -62.64698791503906, loss 11241.963775634766
#    every episode report:      Episode 293 : reward -153.23416137695312, loss 11201.116882324219
#    every episode report:      Episode 294 : reward -164.8628387451172, loss 11021.25747680664
#    every episode report:      Episode 295 : reward -218.73992919921875, loss 10470.94140625
#    every episode report:      Episode 296 : reward -194.31153869628906, loss 11226.367004394531
#    every episode report:      Episode 297 : reward -182.58828735351562, loss 10986.149993896484
#    every episode report:      Episode 298 : reward -149.5907440185547, loss 10829.188568115234
#    every episode report:      Episode 299 : reward -160.77731323242188, loss 10358.707580566406
#    every episode report:      Episode 300 : reward -260.1200866699219, loss 10345.9716796875
# Episode 300 : train_reward -155.35997507523518, train_loss 11373.788761683873
# Episode 300 : eval_reward -77.51727294921875, eval_loss 10492.75326538086
#    every episode report:      Episode 301 : reward -204.02493286132812, loss 10892.390197753906
#    every episode report:      Episode 302 : reward -130.3538818359375, loss 10497.374328613281
#    every episode report:      Episode 303 : reward -221.829345703125, loss 10553.452392578125
#    every episode report:      Episode 304 : reward -220.27102661132812, loss 10391.595031738281
#    every episode report:      Episode 305 : reward -138.2818145751953, loss 10569.36459350586
#    every episode report:      Episode 306 : reward -130.99603271484375, loss 10642.552856445312
#    every episode report:      Episode 307 : reward -153.0061492919922, loss 10470.072204589844
#    every episode report:      Episode 308 : reward -141.2674102783203, loss 10481.373626708984
#    every episode report:      Episode 309 : reward -191.8238525390625, loss 10348.195037841797
#    every episode report:      Episode 310 : reward -157.78904724121094, loss 10354.859313964844
#    every episode report:      Episode 311 : reward -147.1230926513672, loss 10313.667053222656
#    every episode report:      Episode 312 : reward -35.025814056396484, loss 10704.906860351562
#    every episode report:      Episode 313 : reward -146.9259033203125, loss 10478.53970336914
#    every episode report:      Episode 314 : reward -147.02565002441406, loss 10217.155548095703
#    every episode report:      Episode 315 : reward -74.78146362304688, loss 10424.451385498047
#    every episode report:      Episode 316 : reward -90.61126708984375, loss 10640.722717285156
#    every episode report:      Episode 317 : reward -141.53793334960938, loss 10261.37368774414
#    every episode report:      Episode 318 : reward -133.8633270263672, loss 10123.841583251953
#    every episode report:      Episode 319 : reward -138.57225036621094, loss 10175.545013427734
#    every episode report:      Episode 320 : reward -117.9613037109375, loss 9823.047668457031
#    every episode report:      Episode 321 : reward -126.16964721679688, loss 10368.948791503906
#    every episode report:      Episode 322 : reward -135.2403564453125, loss 9775.154693603516
#    every episode report:      Episode 323 : reward -308.5132751464844, loss 9960.256256103516
#    every episode report:      Episode 324 : reward -114.9811019897461, loss 9630.52685546875
#    every episode report:      Episode 325 : reward -113.39784240722656, loss 9769.467468261719
#    every episode report:      Episode 326 : reward -135.6720428466797, loss 9562.502075195312
#    every episode report:      Episode 327 : reward -75.83094024658203, loss 9862.643157958984
#    every episode report:      Episode 328 : reward -113.58515930175781, loss 9683.391143798828
#    every episode report:      Episode 329 : reward -64.49232482910156, loss 9653.967529296875
#    every episode report:      Episode 330 : reward -169.58731079101562, loss 9604.64828491211
#    every episode report:      Episode 331 : reward -191.81607055664062, loss 9367.29719543457
#    every episode report:      Episode 332 : reward -122.7828140258789, loss 9347.183486938477
#    every episode report:      Episode 333 : reward -104.67292785644531, loss 9548.016174316406
#    every episode report:      Episode 334 : reward -202.62167358398438, loss 9490.42202758789
#    every episode report:      Episode 335 : reward -31.901771545410156, loss 9472.642272949219
#    every episode report:      Episode 336 : reward -151.00071716308594, loss 9515.4453125
#    every episode report:      Episode 337 : reward -71.9064712524414, loss 9390.091613769531
#    every episode report:      Episode 338 : reward -150.27452087402344, loss 9174.868743896484
#    every episode report:      Episode 339 : reward -94.08468627929688, loss 9484.700988769531
#    every episode report:      Episode 340 : reward -113.36552429199219, loss 9404.417449951172
#    every episode report:      Episode 341 : reward -53.44300842285156, loss 9191.319961547852
#    every episode report:      Episode 342 : reward -182.33641052246094, loss 9190.3046875
#    every episode report:      Episode 343 : reward -306.3644714355469, loss 8937.801467895508
#    every episode report:      Episode 344 : reward -77.07902526855469, loss 9113.7900390625
#    every episode report:      Episode 345 : reward -111.69833374023438, loss 9190.988159179688
#    every episode report:      Episode 346 : reward -228.49517822265625, loss 9380.327880859375
#    every episode report:      Episode 347 : reward -69.9141845703125, loss 9221.560424804688
#    every episode report:      Episode 348 : reward -119.69062805175781, loss 9184.715301513672
#    every episode report:      Episode 349 : reward -83.62489318847656, loss 8803.995849609375
#    every episode report:      Episode 350 : reward -138.33786010742188, loss 8887.263595581055
# Episode 350 : train_reward -136.4819349172164, train_loss 9849.915838747609
# Episode 350 : eval_reward -110.81800842285156, eval_loss 8861.526931762695
#    every episode report:      Episode 351 : reward -122.30160522460938, loss 8881.741119384766
#    every episode report:      Episode 352 : reward -136.33131408691406, loss 9134.255004882812
#    every episode report:      Episode 353 : reward -94.22972106933594, loss 8966.083511352539
#    every episode report:      Episode 354 : reward -216.4585418701172, loss 8932.503158569336
#    every episode report:      Episode 355 : reward -106.08831787109375, loss 8808.673629760742
#    every episode report:      Episode 356 : reward -55.422386169433594, loss 8630.368133544922
#    every episode report:      Episode 357 : reward -128.64825439453125, loss 8896.138275146484
#    every episode report:      Episode 358 : reward -53.56022644042969, loss 8770.454406738281
#    every episode report:      Episode 359 : reward -40.247344970703125, loss 8638.106384277344
#    every episode report:      Episode 360 : reward -52.53819274902344, loss 8655.11685180664
#    every episode report:      Episode 361 : reward -231.5926513671875, loss 8840.096740722656
#    every episode report:      Episode 362 : reward -104.71342468261719, loss 8512.796371459961
#    every episode report:      Episode 363 : reward -148.78445434570312, loss 8731.869506835938
#    every episode report:      Episode 364 : reward -127.35662841796875, loss 8239.999954223633
#    every episode report:      Episode 365 : reward -177.0656280517578, loss 8587.709655761719
#    every episode report:      Episode 366 : reward -124.27162170410156, loss 8487.818344116211
#    every episode report:      Episode 367 : reward -168.6826934814453, loss 8706.415435791016
#    every episode report:      Episode 368 : reward -186.90040588378906, loss 8313.016372680664
#    every episode report:      Episode 369 : reward -83.39253997802734, loss 8207.115631103516
#    every episode report:      Episode 370 : reward -129.62376403808594, loss 8389.586227416992
#    every episode report:      Episode 371 : reward -195.41123962402344, loss 8659.400817871094
#    every episode report:      Episode 372 : reward -142.71128845214844, loss 8551.311386108398
#    every episode report:      Episode 373 : reward -122.04072570800781, loss 8234.893783569336
#    every episode report:      Episode 374 : reward -183.19876098632812, loss 8369.309295654297
#    every episode report:      Episode 375 : reward -144.0847625732422, loss 8446.81999206543
#    every episode report:      Episode 376 : reward -198.55606079101562, loss 8574.210830688477
#    every episode report:      Episode 377 : reward -304.24908447265625, loss 8166.087936401367
#    every episode report:      Episode 378 : reward -155.30752563476562, loss 8235.135833740234
#    every episode report:      Episode 379 : reward -182.3200225830078, loss 8301.865661621094
#    every episode report:      Episode 380 : reward -154.2523651123047, loss 8372.281539916992
#    every episode report:      Episode 381 : reward -130.346435546875, loss 8383.850830078125
#    every episode report:      Episode 382 : reward -61.54859924316406, loss 8278.098190307617
#    every episode report:      Episode 383 : reward -198.5277099609375, loss 8298.72624206543
#    every episode report:      Episode 384 : reward -72.41801452636719, loss 8111.215850830078
#    every episode report:      Episode 385 : reward -148.29470825195312, loss 8125.610458374023
#    every episode report:      Episode 386 : reward -47.56858825683594, loss 8307.263076782227
#    every episode report:      Episode 387 : reward -154.95828247070312, loss 8043.87532043457
#    every episode report:      Episode 388 : reward -161.3927001953125, loss 8213.54573059082
#    every episode report:      Episode 389 : reward -424.1063232421875, loss 8200.843704223633
#    every episode report:      Episode 390 : reward -108.0948257446289, loss 8165.684051513672
#    every episode report:      Episode 391 : reward -52.33977508544922, loss 8172.100311279297
#    every episode report:      Episode 392 : reward -152.37696838378906, loss 8217.820129394531
#    every episode report:      Episode 393 : reward -107.27287292480469, loss 8225.31478881836
#    every episode report:      Episode 394 : reward -129.3945770263672, loss 8147.230926513672
#    every episode report:      Episode 395 : reward -96.13040161132812, loss 8225.335174560547
#    every episode report:      Episode 396 : reward -96.72550201416016, loss 8160.452301025391
#    every episode report:      Episode 397 : reward -106.72853088378906, loss 8116.8272705078125
#    every episode report:      Episode 398 : reward -219.74368286132812, loss 8387.01921081543
#    every episode report:      Episode 399 : reward -204.4689178466797, loss 8137.948028564453
#    every episode report:      Episode 400 : reward -217.3245391845703, loss 7958.028396606445
# Episode 400 : train_reward -141.68936671042928, train_loss 8431.835579385563
# Episode 400 : eval_reward -82.10591125488281, eval_loss 7892.843353271484
#    every episode report:      Episode 401 : reward -87.78575134277344, loss 7989.772705078125
#    every episode report:      Episode 402 : reward -64.10671997070312, loss 7768.687301635742
#    every episode report:      Episode 403 : reward -134.85426330566406, loss 8134.801528930664
#    every episode report:      Episode 404 : reward -126.49183654785156, loss 7839.030075073242
#    every episode report:      Episode 405 : reward -114.23692321777344, loss 8009.92903137207
#    every episode report:      Episode 406 : reward -206.63815307617188, loss 7877.747909545898
#    every episode report:      Episode 407 : reward -106.48672485351562, loss 8023.207229614258
#    every episode report:      Episode 408 : reward -92.59872436523438, loss 7788.310256958008
#    every episode report:      Episode 409 : reward -125.26759338378906, loss 7958.722457885742
#    every episode report:      Episode 410 : reward -189.5101318359375, loss 7659.527648925781
#    every episode report:      Episode 411 : reward -129.87628173828125, loss 7554.313690185547
#    every episode report:      Episode 412 : reward -186.87933349609375, loss 7756.954437255859
#    every episode report:      Episode 413 : reward -128.298583984375, loss 7754.215682983398
#    every episode report:      Episode 414 : reward -202.26858520507812, loss 8052.762832641602
#    every episode report:      Episode 415 : reward -130.015380859375, loss 7614.667236328125
#    every episode report:      Episode 416 : reward -127.05859375, loss 7744.924987792969
#    every episode report:      Episode 417 : reward -86.00216674804688, loss 7820.79801940918
#    every episode report:      Episode 418 : reward -128.9880828857422, loss 7615.957778930664
#    every episode report:      Episode 419 : reward -31.39417266845703, loss 7731.488586425781
#    every episode report:      Episode 420 : reward -77.95210266113281, loss 7641.023208618164
#    every episode report:      Episode 421 : reward -99.297119140625, loss 7849.715362548828
#    every episode report:      Episode 422 : reward -68.25144958496094, loss 7702.313980102539
#    every episode report:      Episode 423 : reward -193.34080505371094, loss 7657.357772827148
#    every episode report:      Episode 424 : reward -152.24722290039062, loss 7839.08610534668
#    every episode report:      Episode 425 : reward -100.55653381347656, loss 7625.146224975586
#    every episode report:      Episode 426 : reward -188.5269317626953, loss 7540.04133605957
#    every episode report:      Episode 427 : reward -130.9823760986328, loss 7694.48210144043
#    every episode report:      Episode 428 : reward -126.73839569091797, loss 7704.280517578125
#    every episode report:      Episode 429 : reward -52.61927795410156, loss 7502.60334777832
#    every episode report:      Episode 430 : reward -155.8628387451172, loss 7710.4776611328125
#    every episode report:      Episode 431 : reward -123.11994934082031, loss 7572.358535766602
#    every episode report:      Episode 432 : reward -127.3739013671875, loss 7695.592483520508
#    every episode report:      Episode 433 : reward -73.77398681640625, loss 7613.993240356445
#    every episode report:      Episode 434 : reward -154.43206787109375, loss 7624.821594238281
#    every episode report:      Episode 435 : reward -132.00338745117188, loss 7503.946365356445
#    every episode report:      Episode 436 : reward -91.21414184570312, loss 7450.791320800781
#    every episode report:      Episode 437 : reward -125.04231262207031, loss 7444.702529907227
#    every episode report:      Episode 438 : reward -100.9630126953125, loss 7424.696472167969
#    every episode report:      Episode 439 : reward -168.36880493164062, loss 7473.978439331055
#    every episode report:      Episode 440 : reward -157.0914306640625, loss 7408.545959472656
#    every episode report:      Episode 441 : reward -69.71477508544922, loss 7466.457229614258
#    every episode report:      Episode 442 : reward -204.746337890625, loss 7204.414505004883
#    every episode report:      Episode 443 : reward -109.92791748046875, loss 7523.840103149414
#    every episode report:      Episode 444 : reward -112.47312927246094, loss 7609.577423095703
#    every episode report:      Episode 445 : reward -144.4744873046875, loss 7189.759613037109
#    every episode report:      Episode 446 : reward -241.4705810546875, loss 7216.758834838867
#    every episode report:      Episode 447 : reward -29.926658630371094, loss 7546.615188598633
#    every episode report:      Episode 448 : reward -183.6969451904297, loss 7120.870147705078
#    every episode report:      Episode 449 : reward -136.11758422851562, loss 7119.182144165039
#    every episode report:      Episode 450 : reward -81.07598876953125, loss 7396.740875244141
# Episode 450 : train_reward -127.16458098742427, train_loss 7640.27039072465
# Episode 450 : eval_reward -85.80430603027344, eval_loss 7296.502624511719
#    every episode report:      Episode 451 : reward -85.63610076904297, loss 7504.492416381836
#    every episode report:      Episode 452 : reward -203.33560180664062, loss 7174.3282470703125
#    every episode report:      Episode 453 : reward -64.10841369628906, loss 7312.592498779297
#    every episode report:      Episode 454 : reward -82.97990417480469, loss 7421.923919677734
#    every episode report:      Episode 455 : reward -109.75889587402344, loss 7388.882904052734
#    every episode report:      Episode 456 : reward -117.66455078125, loss 7400.775817871094
#    every episode report:      Episode 457 : reward -183.6949920654297, loss 7459.228485107422
#    every episode report:      Episode 458 : reward -67.30805206298828, loss 7272.178985595703
#    every episode report:      Episode 459 : reward -78.6416015625, loss 7421.843826293945
#    every episode report:      Episode 460 : reward -115.54800415039062, loss 7359.853897094727
#    every episode report:      Episode 461 : reward -27.64586639404297, loss 7213.186996459961
#    every episode report:      Episode 462 : reward -199.25177001953125, loss 7056.212066650391
#    every episode report:      Episode 463 : reward -199.52064514160156, loss 7202.354202270508
#    every episode report:      Episode 464 : reward -124.32450866699219, loss 7241.728820800781
#    every episode report:      Episode 465 : reward -103.43547821044922, loss 7138.0677490234375
#    every episode report:      Episode 466 : reward -90.19999694824219, loss 6920.201858520508
#    every episode report:      Episode 467 : reward -96.50543975830078, loss 6891.49641418457
#    every episode report:      Episode 468 : reward -94.1885986328125, loss 7175.709487915039
#    every episode report:      Episode 469 : reward -86.49614715576172, loss 7008.578384399414
#    every episode report:      Episode 470 : reward -176.4704132080078, loss 7354.852478027344
#    every episode report:      Episode 471 : reward -84.11245727539062, loss 6995.213241577148
#    every episode report:      Episode 472 : reward -59.725555419921875, loss 6921.635391235352
#    every episode report:      Episode 473 : reward -116.31266784667969, loss 7098.217514038086
#    every episode report:      Episode 474 : reward -90.67156982421875, loss 6905.408843994141
#    every episode report:      Episode 475 : reward -261.88323974609375, loss 7172.356842041016
#    every episode report:      Episode 476 : reward -137.72352600097656, loss 6877.237167358398
#    every episode report:      Episode 477 : reward -146.49896240234375, loss 7021.236663818359
#    every episode report:      Episode 478 : reward -42.84223937988281, loss 6843.832244873047
#    every episode report:      Episode 479 : reward -116.61277770996094, loss 6711.41813659668
#    every episode report:      Episode 480 : reward -105.07780456542969, loss 7205.763595581055
#    every episode report:      Episode 481 : reward -65.50977325439453, loss 7029.987365722656
#    every episode report:      Episode 482 : reward -110.04562377929688, loss 6862.157119750977
#    every episode report:      Episode 483 : reward -142.67181396484375, loss 6810.169815063477
#    every episode report:      Episode 484 : reward -128.3797607421875, loss 6899.688629150391
#    every episode report:      Episode 485 : reward -97.95237731933594, loss 6961.810134887695
#    every episode report:      Episode 486 : reward -154.21669006347656, loss 6948.245208740234
#    every episode report:      Episode 487 : reward -120.64569091796875, loss 6933.676040649414
#    every episode report:      Episode 488 : reward -78.96388244628906, loss 6773.1617431640625
#    every episode report:      Episode 489 : reward -128.15365600585938, loss 6937.211608886719
#    every episode report:      Episode 490 : reward -236.26846313476562, loss 7122.2205810546875
#    every episode report:      Episode 491 : reward -178.02188110351562, loss 6620.87060546875
#    every episode report:      Episode 492 : reward -115.74320983886719, loss 6711.174072265625
#    every episode report:      Episode 493 : reward -155.94644165039062, loss 7094.509826660156
#    every episode report:      Episode 494 : reward -61.325843811035156, loss 6823.742828369141
#    every episode report:      Episode 495 : reward -241.96298217773438, loss 6982.791442871094
#    every episode report:      Episode 496 : reward -192.79722595214844, loss 6781.88493347168
#    every episode report:      Episode 497 : reward -110.08488464355469, loss 6839.124008178711
#    every episode report:      Episode 498 : reward -204.30126953125, loss 6756.044143676758
#    every episode report:      Episode 499 : reward -160.44479370117188, loss 6803.773788452148
#    every episode report:      Episode 500 : reward -76.7269287109375, loss 6755.363143920898
# Episode 500 : train_reward -125.54310296506299, train_loss 7048.225571301518
# Episode 500 : eval_reward -58.82551574707031, eval_loss 6754.006591796875

# %%
def plot_pic(log):
    """ Parse the logs """
    total = {p:np.array([getattr(l.total,p) for l in log]) for p in dyn.parameters}
    cities = {c:{p:np.array([getattr(l.city[c],p) for l in log]) for p in dyn.parameters} for c in dyn.cities}
    actions = {a:np.array([l.action[a] for l in log]) for a in log[0].action.keys()}

    from matplotlib.ticker import MultipleLocator
    fig = plt.figure(figsize=(14,10))
    ax_leftstate = plt.subplot2grid(shape=(9, 2), loc=(0, 0), rowspan=4)
    ax_leftobs = plt.subplot2grid(shape=(9, 2), loc=(4, 0), rowspan=3)
    ax_leftactions = plt.subplot2grid(shape=(9, 2), loc=(7, 0), rowspan=2)
    ax_right = [plt.subplot2grid(shape=(9, 2), loc=(0, 1), colspan=1)]
    ax_right += [plt.subplot2grid(shape=(9, 2), loc=(i, 1), colspan=1) for i in range(1,9)]
    ax_right = {k:ax_right[_id] for _id,k in enumerate(cities.keys())}

    [ax_leftstate.plot(y) for y in total.values()]
    ax_leftstate.legend(total.keys())
    ax_leftstate.set_title('Full state')
    ax_leftstate.set_ylabel('number of people in each state')

    [ax_leftobs.plot(total[y]) for y in ['infected','dead']]
    ax_leftobs.legend(['infected','dead'])
    ax_leftobs.set_title('Observable state')
    ax_leftobs.set_ylabel('number of people in each state')

    ax_leftactions.imshow(np.array([v for v in actions.values()]).astype(np.uint8),aspect='auto')
    ax_leftactions.set_title('Actions')
    ax_leftactions.set_yticks([0,1,2,3])
    ax_leftactions.set_yticklabels(list(actions.keys()))
    ax_leftactions.set_xlabel('time (in weeks)')

    [ax.plot(cities[c]['infected']) for c, ax in ax_right.items()]
    [ax.plot(cities[c]['dead']) for c, ax in ax_right.items()]
    [ax.set_ylabel(c) for c, ax in ax_right.items()]
    [ax.xaxis.set_major_locator(plt.NullLocator()) for c, ax in ax_right.items()]
    ax_right['Zürich'].set_xlabel('time (in weeks)')
    ax_right['Zürich'].xaxis.set_major_locator(MultipleLocator(2.000))

    fig.tight_layout()
    plt.show()

# %%
testagent = DQN_Agent(env_m, epsilon=0.7, batch_size=BATCH_SIZE, buffer_size=20000, GAMMA=GAMMA,lr = LR, device=device ,
                    policy_net=policy_net_m, target_net=target_net_m)
testagent.load_model("DQN_best_Q4.pth")
log2 = []
finished = False
obs, info = env_m.reset(100)

while not finished:
    action = testagent.act(obs,0)
    obs, R, finished, info = env_m.step(action)
    log2.append(info) # save the information dict for logging
    if finished:
        break

plot_pic(log2)

# %%
one_episode_decay(env_m,DQNagent_m,1,0.7,0.2,500,450)
# Out:
# (-120.44697570800781, 6844.538772583008)
