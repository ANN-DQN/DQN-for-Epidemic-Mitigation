# %%
# implement the dqn for me using pytorch and openai gym
import matplotlib.pyplot as plt
from gym import spaces
import json
"""Environment imports"""
from epidemic_env.env       import Env, Log
from epidemic_env.dynamics  import ModelDynamics, Observation
from epidemic_env.visualize import Visualize
from epidemic_env.agent     import Agent

"""Pytorch and numpy imports"""
import numpy as np
import torch
from torch import nn

# %matplotlib inline
dyn = ModelDynamics('config/switzerland.yaml')   # load the switzerland map

# get the cuda
# import optimimzer
import torch.optim as optim
import torch.nn.functional as F
import random
import math
from collections import namedtuple
from itertools import count
from IPython import display
from torch.autograd import Variable
from collections import deque
import time

# %%
class DQN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQN, self).__init__()
        self.linear1 = nn.Linear(input_dim, 64)
        self.linear2 = nn.Linear(64, 32)
        self.linear3 = nn.Linear(32, 16)
        self.linear4 = nn.Linear(16, output_dim)
        
    def forward(self, x):
        x = x.view(-1, input_dim)
        x = torch.relu(self.linear1(x))
        x = torch.relu(self.linear2(x)) 
        x = torch.relu(self.linear3(x))
        x = self.linear4(x)
        return x 

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device}")
def int_to_tensor(x):
    return torch.tensor(x, dtype=torch.float32, device=device).unsqueeze(0)
# Out:
# Using cuda

# %%
action_space        =   spaces.Discrete(5)
observation_space   =   spaces.Box( low=0,
                                    high=1,
                                    shape=(2, dyn.n_cities, dyn.env_step_length),
                                    dtype=np.float16)
print(f"sampled action : {action_space.sample()}")
print("Sampled observation")
plt.matshow(observation_space.sample()[1,:,:])
plt.show()

SCALE = 100
ACTION_NULL = 0
ACTION_CONFINE = 1
ACTION_ISOLATE = 2
ACTION_HOSPITAL = 3
ACTION_VACCINATE = 4
def action_preprocessor_m(a:torch.Tensor, dyn:ModelDynamics):
    action = { # DO NOTHING
        'confinement': bool(dyn.get_action()['confinement']), 
        'isolation': bool(dyn.get_action()['isolation']), 
        'hospital': bool(dyn.get_action()['hospital']), 
        'vaccinate': bool(dyn.get_action()['vaccinate']),
    }
    
    if a == ACTION_CONFINE:
        action['confinement'] = bool( 1 - dyn.get_action()['confinement'] ) 
    elif a == ACTION_ISOLATE:
        action['isolation'] = bool( 1 - dyn.get_action()['isolation'] )
    elif a == ACTION_VACCINATE:
        action['vaccinate'] = bool( 1 - dyn.get_action()['vaccinate'] )
    elif a == ACTION_HOSPITAL:
        action['hospital'] = bool( 1 - dyn.get_action()['hospital'] )
        
    return action

def observation_preprocessor_m(obs: Observation, dyn:ModelDynamics):
    infected = SCALE * np.power(np.array([np.array(obs.city[c].infected)/obs.pop[c] for c in dyn.cities]), 0.25)
    dead = SCALE * np.power( np.array([np.array(obs.city[c].dead)/obs.pop[c] for c in dyn.cities]), 0.25)
    confined = np.ones_like(dead)*int((dyn.get_action()['confinement']))
    isolationed = np.ones_like(dead)*int((dyn.get_action()['isolation']))
    hospitaled = np.ones_like(dead)*int((dyn.get_action()['hospital']))
    vaccinated = np.ones_like(dead)*int((dyn.get_action()['vaccinate']))

    return torch.Tensor(np.stack((infected, dead, confined, isolationed, hospitaled, vaccinated))).unsqueeze(0)
# Out:
# sampled action : 4
# Sampled observation

# %%
env_m = Env(  dyn,
            action_space=action_space,
            observation_space=observation_space,
            action_preprocessor=action_preprocessor_m,
            observation_preprocessor=observation_preprocessor_m,
            )

# %%
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward')) # define the transition tuple

class DQN_Agent(Agent):
    def __init__(self,  env:Env, epsilon:float = 0.7, batch_size: int = 2048, buffer_size: int = 20000, device = 'cuda', GAMMA : float = 0.9,
                 lr : float = 1e-5, policy_net = None, target_net = None, optimizer = None,
                # Additionnal parameters to be added here
                ):
        self.epsilon = epsilon
        self.env = env
        self.batch_size = batch_size
        self.buffer_size = buffer_size
        self.memory_initial()
        self.device = device
        self.GAMMA = GAMMA
        self.lr = lr
        self.policy_net = policy_net
        self.target_net = target_net
        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.lr)

    def save_model(self, savepath):
        # This is where one would define the routine for loading a pre-trained model
        torch.save(self.policy_net.state_dict(), savepath)
        pass

    def load_model(self, savepath):
        # This is where one would define the routine for saving the weights for a trained model
        self.policy_net.load_state_dict(torch.load(savepath))
        self.target_net.load_state_dict(self.policy_net.state_dict())
        pass

    def reset(self,):
        # This should be called when the environment is reset
        pass
    
    # the action function for Q3a
    def act(self, obs, temp_epsilon):
        # write the epsilon-greedy policy here
        if random.random() < temp_epsilon:
            return int_to_tensor( self.env.action_space.sample()).unsqueeze(0) 
        else:
            m = self.policy_net(obs.to(self.device)).max(1)[1].view(1, 1)
            return m # return the action with the highest q-value
    
    # the action functio for Q3b
    def act_decay(self, obs, epsilon0, epsilonmin, Tmax, t):
        temp_epsilon = np.max([epsilon0*(Tmax-t)/Tmax, epsilonmin])
        return self.act(obs, temp_epsilon)
        
    def memory_initial(self):
        # initialize the memory
        self.memory = deque([],maxlen= self.buffer_size) # define the memory as a deque of size capacity

    def memory_push(self, transition):
        # push a transition into the memory
        self.memory.append(transition)

    def memory_sample(self):
        # sample a batch from memory
        return random.sample(self.memory, self.batch_size)
    
    def memory_len(self):
        # return the length of the memory
        return len(self.memory)
    
    def optimize_model(self, train = True):
        # This is where one would define the optimization step of an RL algorithm
        if self.memory_len() < self.batch_size:
            return 0
        transitions = self.memory_sample()

        batch = Transition(*zip(*transitions)) # unzip the batch

        non_final_mask = torch.tensor(tuple(map(lambda s: s is not None, batch.next_state)), device= self.device, dtype=torch.bool).to(device)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None]).to(device)

        state_batch = torch.cat(batch.state).to(device)
        
        action_batch = torch.cat(batch.action).to(device)
        reward_batch = torch.cat(batch.reward).squeeze().to(device)

        action_batch = action_batch.long()
        state_action_values = self.policy_net(state_batch).gather(1, action_batch).to(device)
        next_state_values = torch.zeros(self.batch_size, device= self.device)


        with torch.no_grad():
            next_state_values[non_final_mask] = self.target_net(non_final_next_states).max(1)[0]
        # Compute the expected Q values

        expected_state_action_values = (next_state_values * self.GAMMA) + reward_batch
                
        criterion = nn.MSELoss() # define the loss function

        loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))
        
        if train == True:
            # Optimize the model
            self.optimizer.zero_grad()
            loss.backward()
            # In-place gradient clipping
            torch.nn.utils.clip_grad_value_(self.policy_net.parameters(), 100) 
            self.optimizer.step()
        return loss.item()
    
    def update_target_model(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

# %%
random_seed = 42 
BATCH_SIZE = 2048
GAMMA = 0.9
LR = 1e-3
input_dim = 6 * dyn.n_cities * dyn.env_step_length

state, info = env_m.reset(42)


# Initialize policy and target network
policy_net_m = DQN(input_dim, 5).to(device)
target_net_m = DQN(input_dim, 5).to(device)
# Initialize the target network to be the same as the policy network
target_net_m.load_state_dict(policy_net_m.state_dict()) 


DQNagent_m = DQN_Agent(env_m, epsilon=0.7, batch_size=BATCH_SIZE, buffer_size=20000, GAMMA=GAMMA,lr = LR, device=device ,
                    policy_net=policy_net_m, target_net=target_net_m)



def one_episode_decay(env,agent,random_seed, epsilon0, epsilonmin, Tmax, t):
    state, _ = env.reset(random_seed)
    done = False
    total_reward = 0
    total_loss = 0

    while not done:
        action = agent.act_decay(state, epsilon0, epsilonmin, Tmax, t)
        next_state, reward, done, _ = env.step(action)
        agent.memory_push(Transition(state, action, next_state, reward))
        state = next_state
        total_reward += reward
        loss = agent.optimize_model()
        total_loss += loss
    
    return total_reward.item(), total_loss


def eval_one(env,agent, random_seed):
    state, _ = env.reset(random_seed)
    done = False
    total_reward = 0
    total_loss = 0

    while not done:
        action = agent.act(state,0)
        next_state, reward, done, _ = env.step(action)
        state = next_state
        total_reward += reward
        loss = agent.optimize_model(train = False)
        total_loss += loss
    
    return total_reward.item(), total_loss



def train_Q4(it:int):
    train_loss_trace = []
    train_reward_trace = []
    eval_loss_trace = []
    eval_reward_trace = []

    best = -np.inf

    for i in range(1,501):
        reward, loss = one_episode_decay(env_m,DQNagent_m,i,0.7,0.2,500,i)
        train_loss_trace.append(loss)
        train_reward_trace.append(reward)
        print(f"   every episode report:      Episode {i} : reward {reward}, loss {loss}")
        if i % 5 == 0:
            DQNagent_m.update_target_model()
        if i % 50 == 0 :
            tuple_list = np.array([eval_one(env_m,DQNagent_m,m) for m in range(20)])
            eval_losss = np.mean(tuple_list,axis = 0)[1]
            eval_rewards = np.mean(tuple_list,axis = 0)[0]

            eval_loss_trace.append(eval_losss)
            eval_reward_trace.append(eval_rewards)
            train_loss = np.mean(train_loss_trace[i-50:i-1])
            train_reward = np.mean(train_reward_trace[i-50:i-1])
            
            if eval_rewards > best:
                best = eval_rewards
                torch.save(DQNagent_m.policy_net.state_dict(), "DQN_best_Q4.pth")
            print(f"Episode {i} : train_reward {train_reward}, train_loss {train_loss}")
            print(f"Episode {i} : eval_reward {eval_rewards}, eval_loss {eval_losss}")

    with open('Q4_train_loss_'+ str(it) +'.json', 'w') as f: json.dump(train_loss_trace, f)
    with open('Q4_train_reward_'+ str(it) +'.json', 'w') as f: json.dump(train_reward_trace, f)
    with open('Q4_eval_loss_'+ str(it) +'.json', 'w') as f: json.dump(eval_loss_trace, f)
    with open('Q4_eval_reward_'+ str(it) +'.json', 'w') as f: json.dump(eval_reward_trace, f)

# %%
for i in range(3):
    random_seed = 42 
    BATCH_SIZE = 2048
    GAMMA = 0.9
    LR = 1e-3
    input_dim = 6 * dyn.n_cities * dyn.env_step_length

    state, info = env_m.reset(42)


    # Initialize policy and target network
    policy_net_m = DQN(input_dim, 5).to(device)
    target_net_m = DQN(input_dim, 5).to(device)
    # Initialize the target network to be the same as the policy network
    target_net_m.load_state_dict(policy_net_m.state_dict()) 


    DQNagent_m = DQN_Agent(env_m, epsilon=0.7, batch_size=BATCH_SIZE, buffer_size=20000, GAMMA=GAMMA,lr = LR, device=device ,
                        policy_net=policy_net_m, target_net=target_net_m)
    
    train_Q4(i+1)
# Out:
#    every episode report:      Episode 1 : reward -259.1621398925781, loss 0
#    every episode report:      Episode 2 : reward -154.67593383789062, loss 0
#    every episode report:      Episode 3 : reward -85.58553314208984, loss 0
#    every episode report:      Episode 4 : reward -72.55989837646484, loss 0
#    every episode report:      Episode 5 : reward -3.9907054901123047, loss 0
#    every episode report:      Episode 6 : reward -252.66616821289062, loss 0
#    every episode report:      Episode 7 : reward -33.44057846069336, loss 0
#    every episode report:      Episode 8 : reward -30.618391036987305, loss 0
#    every episode report:      Episode 9 : reward -94.19422149658203, loss 0
#    every episode report:      Episode 10 : reward -48.38188171386719, loss 0
#    every episode report:      Episode 11 : reward -102.57791900634766, loss 0
#    every episode report:      Episode 12 : reward -80.50305938720703, loss 0
#    every episode report:      Episode 13 : reward -81.82987213134766, loss 0
#    every episode report:      Episode 14 : reward -181.049560546875, loss 0
#    every episode report:      Episode 15 : reward -221.7464599609375, loss 0
#    every episode report:      Episode 16 : reward -105.90398406982422, loss 0
#    every episode report:      Episode 17 : reward -162.11386108398438, loss 0
#    every episode report:      Episode 18 : reward -212.70533752441406, loss 0
#    every episode report:      Episode 19 : reward -73.55830383300781, loss 0
#    every episode report:      Episode 20 : reward -214.24588012695312, loss 0
#    every episode report:      Episode 21 : reward -252.39254760742188, loss 0

# %%
train_Q4()
# Out:
#    every episode report:      Episode 1 : reward -199.27362060546875, loss 0
#    every episode report:      Episode 2 : reward -169.05331420898438, loss 0
#    every episode report:      Episode 3 : reward -102.18849182128906, loss 0
#    every episode report:      Episode 4 : reward -3.238718032836914, loss 0
#    every episode report:      Episode 5 : reward -51.24624252319336, loss 0
#    every episode report:      Episode 6 : reward -16.79353141784668, loss 0
#    every episode report:      Episode 7 : reward 55.91352462768555, loss 0
#    every episode report:      Episode 8 : reward -76.7371597290039, loss 0
#    every episode report:      Episode 9 : reward -93.44534301757812, loss 0
#    every episode report:      Episode 10 : reward -164.25216674804688, loss 0
#    every episode report:      Episode 11 : reward -279.9055480957031, loss 0
#    every episode report:      Episode 12 : reward -46.03398132324219, loss 0
#    every episode report:      Episode 13 : reward 25.19533348083496, loss 0
#    every episode report:      Episode 14 : reward -66.6231460571289, loss 0
#    every episode report:      Episode 15 : reward -74.92704010009766, loss 0
#    every episode report:      Episode 16 : reward -183.30856323242188, loss 0
#    every episode report:      Episode 17 : reward -127.11070251464844, loss 0
#    every episode report:      Episode 18 : reward -91.73023223876953, loss 0
#    every episode report:      Episode 19 : reward -42.86241149902344, loss 0
#    every episode report:      Episode 20 : reward -268.08953857421875, loss 0
#    every episode report:      Episode 21 : reward -201.4385986328125, loss 0
#    every episode report:      Episode 22 : reward -202.2315216064453, loss 0
#    every episode report:      Episode 23 : reward -119.37593078613281, loss 0
#    every episode report:      Episode 24 : reward -78.30292510986328, loss 0
#    every episode report:      Episode 25 : reward 6.798039436340332, loss 0
#    every episode report:      Episode 26 : reward -13.354677200317383, loss 0
#    every episode report:      Episode 27 : reward -131.84632873535156, loss 0
#    every episode report:      Episode 28 : reward -237.07003784179688, loss 0
#    every episode report:      Episode 29 : reward -217.8635711669922, loss 0
#    every episode report:      Episode 30 : reward -202.50523376464844, loss 0
#    every episode report:      Episode 31 : reward -12.58104133605957, loss 0
#    every episode report:      Episode 32 : reward 21.692264556884766, loss 0
#    every episode report:      Episode 33 : reward -133.15562438964844, loss 0
#    every episode report:      Episode 34 : reward -106.11610412597656, loss 0
#    every episode report:      Episode 35 : reward -187.24722290039062, loss 0
#    every episode report:      Episode 36 : reward -187.42376708984375, loss 0
#    every episode report:      Episode 37 : reward -98.1114730834961, loss 0
#    every episode report:      Episode 38 : reward -18.39246368408203, loss 0
#    every episode report:      Episode 39 : reward -97.14466094970703, loss 0
#    every episode report:      Episode 40 : reward -92.89424133300781, loss 0
#    every episode report:      Episode 41 : reward -100.00244140625, loss 0
#    every episode report:      Episode 42 : reward -104.74778747558594, loss 0
#    every episode report:      Episode 43 : reward -107.64540100097656, loss 0
#    every episode report:      Episode 44 : reward -63.3203010559082, loss 0
#    every episode report:      Episode 45 : reward -5.071321487426758, loss 0
#    every episode report:      Episode 46 : reward -204.6134033203125, loss 0
#    every episode report:      Episode 47 : reward -55.8189697265625, loss 0
#    every episode report:      Episode 48 : reward -133.4582061767578, loss 0
#    every episode report:      Episode 49 : reward -46.651580810546875, loss 0
#    every episode report:      Episode 50 : reward -91.2136459350586, loss 0
# Episode 50 : train_reward -104.19602909866644, train_loss 0.0
# Episode 50 : eval_reward -133.7166748046875, eval_loss 0.0
#    every episode report:      Episode 51 : reward 18.44308090209961, loss 0
#    every episode report:      Episode 52 : reward -106.61811065673828, loss 0
#    every episode report:      Episode 53 : reward -189.5921173095703, loss 0
#    every episode report:      Episode 54 : reward -164.96182250976562, loss 0
#    every episode report:      Episode 55 : reward -164.1730499267578, loss 0
#    every episode report:      Episode 56 : reward -59.110191345214844, loss 0
#    every episode report:      Episode 57 : reward -27.923484802246094, loss 0
#    every episode report:      Episode 58 : reward -36.460323333740234, loss 0
#    every episode report:      Episode 59 : reward 9.567146301269531, loss 0
#    every episode report:      Episode 60 : reward -244.0486297607422, loss 0
#    every episode report:      Episode 61 : reward -78.89958953857422, loss 0
#    every episode report:      Episode 62 : reward -44.05952835083008, loss 0
#    every episode report:      Episode 63 : reward -177.28514099121094, loss 0
#    every episode report:      Episode 64 : reward -305.735107421875, loss 0
#    every episode report:      Episode 65 : reward -128.4478302001953, loss 0
#    every episode report:      Episode 66 : reward -44.13900375366211, loss 0
#    every episode report:      Episode 67 : reward -230.27804565429688, loss 0
#    every episode report:      Episode 68 : reward -84.1133804321289, loss 0
#    every episode report:      Episode 69 : reward -148.66806030273438, loss 4982.364883422852
#    every episode report:      Episode 70 : reward -67.01210021972656, loss 4616.97078704834
#    every episode report:      Episode 71 : reward -4.850212097167969, loss 3435.3351135253906
#    every episode report:      Episode 72 : reward -292.7017822265625, loss 2199.365791320801
#    every episode report:      Episode 73 : reward -57.35506820678711, loss 1689.2791938781738
#    every episode report:      Episode 74 : reward -138.03590393066406, loss 1278.3057250976562
#    every episode report:      Episode 75 : reward -151.60279846191406, loss 974.3348217010498
#    every episode report:      Episode 76 : reward -135.9793701171875, loss 2495.0092849731445
#    every episode report:      Episode 77 : reward -43.056053161621094, loss 1516.252239227295
#    every episode report:      Episode 78 : reward -200.3233184814453, loss 1261.2814674377441
#    every episode report:      Episode 79 : reward -26.21517562866211, loss 1069.1023292541504
#    every episode report:      Episode 80 : reward -22.823301315307617, loss 955.303560256958
#    every episode report:      Episode 81 : reward -81.05500030517578, loss 1671.7585487365723
#    every episode report:      Episode 82 : reward -186.65345764160156, loss 1116.8672828674316
#    every episode report:      Episode 83 : reward -53.2249641418457, loss 901.8008403778076
#    every episode report:      Episode 84 : reward -30.15976333618164, loss 817.9144973754883
#    every episode report:      Episode 85 : reward -53.37785720825195, loss 723.4175052642822
#    every episode report:      Episode 86 : reward -108.939453125, loss 1091.9542198181152
#    every episode report:      Episode 87 : reward -120.00944519042969, loss 758.1280212402344
#    every episode report:      Episode 88 : reward -36.08443069458008, loss 682.5492610931396
#    every episode report:      Episode 89 : reward -141.34413146972656, loss 635.2377796173096
#    every episode report:      Episode 90 : reward -116.23570251464844, loss 597.2093391418457
#    every episode report:      Episode 91 : reward -3.1719441413879395, loss 722.0816764831543
#    every episode report:      Episode 92 : reward -16.852916717529297, loss 555.4796028137207
#    every episode report:      Episode 93 : reward -179.2042694091797, loss 536.5942516326904
#    every episode report:      Episode 94 : reward -141.7470245361328, loss 561.3741855621338
#    every episode report:      Episode 95 : reward -83.95795440673828, loss 504.012131690979
#    every episode report:      Episode 96 : reward -27.964670181274414, loss 654.0685882568359
#    every episode report:      Episode 97 : reward -83.15408325195312, loss 516.2760915756226
#    every episode report:      Episode 98 : reward -228.57566833496094, loss 525.1816835403442
#    every episode report:      Episode 99 : reward -44.8842658996582, loss 470.7999963760376
#    every episode report:      Episode 100 : reward -137.617431640625, loss 454.79473304748535
# Episode 100 : train_reward -103.73582194775952, train_loss 826.8491979715775
# Episode 100 : eval_reward -42.53076171875, eval_loss 877.6359882354736
#    every episode report:      Episode 101 : reward -39.69984436035156, loss 620.2973356246948
#    every episode report:      Episode 102 : reward -22.063796997070312, loss 497.1522026062012
#    every episode report:      Episode 103 : reward -77.03175354003906, loss 461.8531103134155
#    every episode report:      Episode 104 : reward -79.34803771972656, loss 412.4862184524536
#    every episode report:      Episode 105 : reward 18.94846534729004, loss 381.04480838775635
#    every episode report:      Episode 106 : reward -54.3995475769043, loss 507.51433181762695
#    every episode report:      Episode 107 : reward -88.9300765991211, loss 403.8063840866089
#    every episode report:      Episode 108 : reward -112.3011474609375, loss 395.0073175430298
#    every episode report:      Episode 109 : reward -108.71206665039062, loss 377.0484390258789
#    every episode report:      Episode 110 : reward -91.08413696289062, loss 399.5264835357666
#    every episode report:      Episode 111 : reward -11.56452751159668, loss 478.8026351928711
#    every episode report:      Episode 112 : reward -29.667448043823242, loss 370.87615299224854
#    every episode report:      Episode 113 : reward -122.9790267944336, loss 366.5242443084717
#    every episode report:      Episode 114 : reward 19.579896926879883, loss 342.40867710113525
#    every episode report:      Episode 115 : reward -90.83027648925781, loss 323.7054214477539
#    every episode report:      Episode 116 : reward 10.299736022949219, loss 428.811185836792
#    every episode report:      Episode 117 : reward -36.396636962890625, loss 365.11590099334717
#    every episode report:      Episode 118 : reward -9.54556655883789, loss 339.08344554901123
#    every episode report:      Episode 119 : reward -114.56999206542969, loss 342.0335063934326
#    every episode report:      Episode 120 : reward -61.372352600097656, loss 336.38652992248535
#    every episode report:      Episode 121 : reward -96.64226531982422, loss 421.77606773376465
#    every episode report:      Episode 122 : reward -11.479900360107422, loss 347.5977210998535
#    every episode report:      Episode 123 : reward -41.2198600769043, loss 322.6198501586914
#    every episode report:      Episode 124 : reward 13.9987154006958, loss 335.6281213760376
#    every episode report:      Episode 125 : reward -122.63375854492188, loss 330.5763282775879
#    every episode report:      Episode 126 : reward -94.40967559814453, loss 400.2542018890381
#    every episode report:      Episode 127 : reward -132.90284729003906, loss 335.0348787307739
#    every episode report:      Episode 128 : reward -94.33627319335938, loss 312.89849281311035
#    every episode report:      Episode 129 : reward 7.955902099609375, loss 292.24290561676025
#    every episode report:      Episode 130 : reward -26.43903923034668, loss 268.7057375907898
#    every episode report:      Episode 131 : reward -71.39847564697266, loss 350.6121702194214
#    every episode report:      Episode 132 : reward 10.327293395996094, loss 312.03993797302246
#    every episode report:      Episode 133 : reward -66.47447967529297, loss 351.2526025772095
#    every episode report:      Episode 134 : reward -73.30648803710938, loss 313.93783378601074
#    every episode report:      Episode 135 : reward 18.145832061767578, loss 282.7099332809448
#    every episode report:      Episode 136 : reward -80.33184814453125, loss 336.5399055480957
#    every episode report:      Episode 137 : reward -41.5678596496582, loss 291.7055244445801
#    every episode report:      Episode 138 : reward -6.973215103149414, loss 285.61229038238525
#    every episode report:      Episode 139 : reward -30.670385360717773, loss 276.84202003479004
#    every episode report:      Episode 140 : reward -67.27042388916016, loss 282.67459774017334
#    every episode report:      Episode 141 : reward -129.5990753173828, loss 390.5459842681885
#    every episode report:      Episode 142 : reward -87.21774291992188, loss 321.98633575439453
#    every episode report:      Episode 143 : reward -103.91053771972656, loss 322.1387891769409
#    every episode report:      Episode 144 : reward -93.70616912841797, loss 337.1518793106079
#    every episode report:      Episode 145 : reward 18.683917999267578, loss 333.95697498321533
#    every episode report:      Episode 146 : reward -63.45824432373047, loss 375.51762676239014
#    every episode report:      Episode 147 : reward -19.95389175415039, loss 308.88765048980713
#    every episode report:      Episode 148 : reward -64.15225219726562, loss 284.91279888153076
#    every episode report:      Episode 149 : reward -92.53939056396484, loss 274.9695644378662
#    every episode report:      Episode 150 : reward -10.03076457977295, loss 264.29704761505127
# Episode 150 : train_reward -56.02348111600292, train_loss 358.179858295285
# Episode 150 : eval_reward 5.796413898468018, eval_loss 330.7762842178345
#    every episode report:      Episode 151 : reward -13.209212303161621, loss 328.87205696105957
#    every episode report:      Episode 152 : reward -82.20344543457031, loss 293.0960912704468
#    every episode report:      Episode 153 : reward -152.4257049560547, loss 312.4565620422363
#    every episode report:      Episode 154 : reward -39.855831146240234, loss 281.022912979126
#    every episode report:      Episode 155 : reward -64.361572265625, loss 271.66602516174316
#    every episode report:      Episode 156 : reward -134.40602111816406, loss 326.64743423461914
#    every episode report:      Episode 157 : reward -42.2783203125, loss 282.29352283477783
#    every episode report:      Episode 158 : reward -84.65530395507812, loss 282.0490417480469
#    every episode report:      Episode 159 : reward -87.57254028320312, loss 261.2790722846985
#    every episode report:      Episode 160 : reward -20.440134048461914, loss 250.2222194671631
#    every episode report:      Episode 161 : reward -0.3993220329284668, loss 285.592059135437
#    every episode report:      Episode 162 : reward -93.24398040771484, loss 257.68642139434814
#    every episode report:      Episode 163 : reward -178.16775512695312, loss 274.0965242385864
#    every episode report:      Episode 164 : reward -0.6223660707473755, loss 265.7739281654358
#    every episode report:      Episode 165 : reward 8.207496643066406, loss 253.27677631378174
#    every episode report:      Episode 166 : reward -114.0695571899414, loss 288.5690965652466
#    every episode report:      Episode 167 : reward -75.13391876220703, loss 266.52525568008423
#    every episode report:      Episode 168 : reward -28.11520004272461, loss 266.57825469970703
#    every episode report:      Episode 169 : reward -56.36888122558594, loss 248.490140914917
#    every episode report:      Episode 170 : reward -0.004547119140625, loss 271.02612590789795
#    every episode report:      Episode 171 : reward -148.9134063720703, loss 312.55976009368896
#    every episode report:      Episode 172 : reward 31.398601531982422, loss 286.05764865875244
#    every episode report:      Episode 173 : reward -3.5572285652160645, loss 255.6838779449463
#    every episode report:      Episode 174 : reward 8.60595703125, loss 263.496374130249
#    every episode report:      Episode 175 : reward -272.7684020996094, loss 346.8651065826416
#    every episode report:      Episode 176 : reward -16.929920196533203, loss 328.3981285095215
#    every episode report:      Episode 177 : reward 6.939662933349609, loss 281.69964122772217
#    every episode report:      Episode 178 : reward -15.651073455810547, loss 262.72376537323
#    every episode report:      Episode 179 : reward -92.12016296386719, loss 259.8177833557129
#    every episode report:      Episode 180 : reward -38.18169403076172, loss 254.5747561454773
#    every episode report:      Episode 181 : reward 11.449640274047852, loss 301.0864372253418
#    every episode report:      Episode 182 : reward -18.058855056762695, loss 286.2915859222412
#    every episode report:      Episode 183 : reward -133.88046264648438, loss 311.9495906829834
#    every episode report:      Episode 184 : reward -7.188045501708984, loss 280.89147663116455
#    every episode report:      Episode 185 : reward 22.360132217407227, loss 264.7249102592468
#    every episode report:      Episode 186 : reward -85.79546356201172, loss 333.8525094985962
#    every episode report:      Episode 187 : reward -43.94497299194336, loss 333.69068813323975
#    every episode report:      Episode 188 : reward -185.66500854492188, loss 341.58721923828125
#    every episode report:      Episode 189 : reward -27.746498107910156, loss 297.94687938690186
#    every episode report:      Episode 190 : reward -32.08034133911133, loss 277.92720317840576
#    every episode report:      Episode 191 : reward -44.960628509521484, loss 315.4206142425537
#    every episode report:      Episode 192 : reward -26.196081161499023, loss 313.0739116668701
#    every episode report:      Episode 193 : reward -1.5520076751708984, loss 286.8032512664795
#    every episode report:      Episode 194 : reward 2.759044647216797, loss 279.647677898407
#    every episode report:      Episode 195 : reward 4.446171760559082, loss 264.8764567375183
#    every episode report:      Episode 196 : reward -18.83858299255371, loss 305.19134044647217
#    every episode report:      Episode 197 : reward -21.386615753173828, loss 283.8302764892578
#    every episode report:      Episode 198 : reward -62.044227600097656, loss 273.51979064941406
#    every episode report:      Episode 199 : reward 1.988913893699646, loss 264.46352338790894
#    every episode report:      Episode 200 : reward 16.751691818237305, loss 281.74795293807983
# Episode 200 : train_reward -50.34362595908496, train_loss 286.4463613665834
# Episode 200 : eval_reward 14.613024711608887, eval_loss 330.8256549835205
#    every episode report:      Episode 201 : reward 0.7286577224731445, loss 314.98485374450684
#    every episode report:      Episode 202 : reward -60.64569091796875, loss 310.48486614227295
#    every episode report:      Episode 203 : reward -71.30091094970703, loss 297.82373905181885
#    every episode report:      Episode 204 : reward -27.517738342285156, loss 299.4237756729126
#    every episode report:      Episode 205 : reward -86.41954803466797, loss 306.12922286987305
#    every episode report:      Episode 206 : reward -85.4324951171875, loss 409.4827547073364
#    every episode report:      Episode 207 : reward -26.41885757446289, loss 316.7219524383545
#    every episode report:      Episode 208 : reward -22.083715438842773, loss 293.97554206848145
#    every episode report:      Episode 209 : reward 18.58774185180664, loss 283.1742353439331
#    every episode report:      Episode 210 : reward -18.840877532958984, loss 281.9550037384033
#    every episode report:      Episode 211 : reward 30.25613784790039, loss 320.8180732727051
#    every episode report:      Episode 212 : reward -54.154205322265625, loss 320.38398838043213
#    every episode report:      Episode 213 : reward -85.4531021118164, loss 319.0321378707886
#    every episode report:      Episode 214 : reward -14.287800788879395, loss 313.731707572937
#    every episode report:      Episode 215 : reward -51.55205154418945, loss 301.3995122909546
#    every episode report:      Episode 216 : reward 15.325870513916016, loss 316.0660037994385
#    every episode report:      Episode 217 : reward -59.60075378417969, loss 326.4869270324707
#    every episode report:      Episode 218 : reward -29.029556274414062, loss 312.8144702911377
#    every episode report:      Episode 219 : reward -112.15109252929688, loss 314.1834135055542
#    every episode report:      Episode 220 : reward -36.125335693359375, loss 311.6078996658325
#    every episode report:      Episode 221 : reward -55.69731140136719, loss 351.8726348876953
#    every episode report:      Episode 222 : reward -28.882850646972656, loss 328.08110904693604
#    every episode report:      Episode 223 : reward 15.711370468139648, loss 303.89899826049805
#    every episode report:      Episode 224 : reward -13.3094482421875, loss 312.7044897079468
#    every episode report:      Episode 225 : reward -120.8415298461914, loss 324.685320854187
#    every episode report:      Episode 226 : reward -66.8849868774414, loss 380.96723079681396
#    every episode report:      Episode 227 : reward -16.61428451538086, loss 365.9418201446533
#    every episode report:      Episode 228 : reward -8.510473251342773, loss 351.7653350830078
#    every episode report:      Episode 229 : reward -45.232078552246094, loss 328.0177345275879
#    every episode report:      Episode 230 : reward -128.41822814941406, loss 324.1348400115967
#    every episode report:      Episode 231 : reward -140.01368713378906, loss 379.97983837127686
#    every episode report:      Episode 232 : reward -84.48833465576172, loss 355.3722629547119
#    every episode report:      Episode 233 : reward -13.15247917175293, loss 362.40510272979736
#    every episode report:      Episode 234 : reward -21.620765686035156, loss 345.23574447631836
#    every episode report:      Episode 235 : reward 16.375070571899414, loss 335.1069049835205
#    every episode report:      Episode 236 : reward -157.0430450439453, loss 396.8679494857788
#    every episode report:      Episode 237 : reward -4.248968601226807, loss 373.91867542266846
#    every episode report:      Episode 238 : reward -46.73535919189453, loss 349.60319328308105
#    every episode report:      Episode 239 : reward -11.703070640563965, loss 367.0918312072754
#    every episode report:      Episode 240 : reward -53.079261779785156, loss 382.72039890289307
#    every episode report:      Episode 241 : reward 16.88071060180664, loss 390.47617530822754
#    every episode report:      Episode 242 : reward 30.057083129882812, loss 374.95131969451904
#    every episode report:      Episode 243 : reward -35.08063888549805, loss 362.89218521118164
#    every episode report:      Episode 244 : reward 11.161442756652832, loss 335.9644184112549
#    every episode report:      Episode 245 : reward 12.330400466918945, loss 332.82762718200684
#    every episode report:      Episode 246 : reward -40.00611114501953, loss 350.3910551071167
#    every episode report:      Episode 247 : reward -92.17534637451172, loss 341.7963066101074
#    every episode report:      Episode 248 : reward -105.68112182617188, loss 367.0086898803711
#    every episode report:      Episode 249 : reward -16.76337242126465, loss 372.32380771636963
#    every episode report:      Episode 250 : reward -37.78113555908203, loss 356.7934503555298
# Episode 250 : train_reward -40.40371428703775, train_loss 337.1363893820315
# Episode 250 : eval_reward 7.752614974975586, eval_loss 366.9579734802246
#    every episode report:      Episode 251 : reward -51.915035247802734, loss 361.8491163253784
#    every episode report:      Episode 252 : reward -38.612693786621094, loss 346.4517602920532
#    every episode report:      Episode 253 : reward -26.971485137939453, loss 343.64215755462646
#    every episode report:      Episode 254 : reward -32.534393310546875, loss 337.03423500061035
#    every episode report:      Episode 255 : reward -54.787620544433594, loss 327.7908182144165
#    every episode report:      Episode 256 : reward -102.26396942138672, loss 363.12373542785645
#    every episode report:      Episode 257 : reward 13.136550903320312, loss 358.21187019348145
#    every episode report:      Episode 258 : reward -10.600902557373047, loss 335.81296825408936
#    every episode report:      Episode 259 : reward -9.496225357055664, loss 326.99906158447266
#    every episode report:      Episode 260 : reward 15.27599048614502, loss 317.3284492492676
#    every episode report:      Episode 261 : reward 6.973188877105713, loss 348.2158536911011
#    every episode report:      Episode 262 : reward 54.387359619140625, loss 339.0311670303345
#    every episode report:      Episode 263 : reward 28.322839736938477, loss 330.3400182723999
#    every episode report:      Episode 264 : reward -49.523136138916016, loss 332.7603015899658
#    every episode report:      Episode 265 : reward 9.26020336151123, loss 322.667423248291
#    every episode report:      Episode 266 : reward -49.30327606201172, loss 332.9799327850342
#    every episode report:      Episode 267 : reward 11.530674934387207, loss 330.7017307281494
#    every episode report:      Episode 268 : reward -22.16474151611328, loss 336.519832611084
#    every episode report:      Episode 269 : reward 17.27243995666504, loss 326.362717628479
#    every episode report:      Episode 270 : reward 25.23362159729004, loss 328.8265628814697
#    every episode report:      Episode 271 : reward -6.936771392822266, loss 325.3508462905884
#    every episode report:      Episode 272 : reward 34.556514739990234, loss 325.0789394378662
#    every episode report:      Episode 273 : reward -95.21994018554688, loss 309.4230422973633
#    every episode report:      Episode 274 : reward -54.11057662963867, loss 321.45159816741943
#    every episode report:      Episode 275 : reward -51.439056396484375, loss 366.09148120880127
#    every episode report:      Episode 276 : reward 23.299591064453125, loss 337.1786222457886
#    every episode report:      Episode 277 : reward -1.4279513359069824, loss 322.1611919403076
#    every episode report:      Episode 278 : reward -66.14984130859375, loss 315.1652374267578
#    every episode report:      Episode 279 : reward -38.95391845703125, loss 315.8577013015747
#    every episode report:      Episode 280 : reward -101.3056411743164, loss 316.03303623199463
#    every episode report:      Episode 281 : reward -108.76679992675781, loss 329.093789100647
#    every episode report:      Episode 282 : reward 23.159343719482422, loss 324.25479793548584
#    every episode report:      Episode 283 : reward -152.64454650878906, loss 329.77849292755127
#    every episode report:      Episode 284 : reward -23.892763137817383, loss 339.5559778213501
#    every episode report:      Episode 285 : reward 30.681331634521484, loss 330.66517066955566
#    every episode report:      Episode 286 : reward 9.817612648010254, loss 332.37657356262207
#    every episode report:      Episode 287 : reward 21.395721435546875, loss 315.03349685668945
#    every episode report:      Episode 288 : reward -115.29859924316406, loss 324.69633865356445
#    every episode report:      Episode 289 : reward 20.1459903717041, loss 325.82164096832275
#    every episode report:      Episode 290 : reward -15.490338325500488, loss 311.20732402801514
#    every episode report:      Episode 291 : reward 39.466041564941406, loss 313.1647090911865
#    every episode report:      Episode 292 : reward -133.9585723876953, loss 342.72802543640137
#    every episode report:      Episode 293 : reward -15.78729248046875, loss 335.2861108779907
#    every episode report:      Episode 294 : reward -37.88233184814453, loss 322.6229667663574
#    every episode report:      Episode 295 : reward -100.48157501220703, loss 307.61569690704346
#    every episode report:      Episode 296 : reward -48.22514343261719, loss 358.7330551147461
#    every episode report:      Episode 297 : reward -176.2034454345703, loss 365.7773103713989
#    every episode report:      Episode 298 : reward 3.4623026847839355, loss 348.79174423217773
#    every episode report:      Episode 299 : reward 8.601154327392578, loss 342.0330276489258
#    every episode report:      Episode 300 : reward -12.440313339233398, loss 340.3504304885864
# Episode 300 : train_reward -28.497349184386586, train_loss 332.6464828179807
# Episode 300 : eval_reward 33.0445556640625, eval_loss 348.2897605895996
#    every episode report:      Episode 301 : reward 22.802663803100586, loss 337.7686548233032
#    every episode report:      Episode 302 : reward -1.808579921722412, loss 320.6018762588501
#    every episode report:      Episode 303 : reward 12.291923522949219, loss 334.8226900100708
#    every episode report:      Episode 304 : reward 9.929642677307129, loss 315.1186103820801
#    every episode report:      Episode 305 : reward -57.8400764465332, loss 317.76379585266113
#    every episode report:      Episode 306 : reward 0.4783039093017578, loss 348.6013708114624
#    every episode report:      Episode 307 : reward -96.1197738647461, loss 323.0118341445923
#    every episode report:      Episode 308 : reward -21.490741729736328, loss 310.9280958175659
#    every episode report:      Episode 309 : reward 21.34105682373047, loss 304.81936168670654
#    every episode report:      Episode 310 : reward -77.977294921875, loss 334.7122678756714
#    every episode report:      Episode 311 : reward -67.53739929199219, loss 373.16140270233154
#    every episode report:      Episode 312 : reward 35.04585647583008, loss 349.02650356292725
#    every episode report:      Episode 313 : reward 6.605442047119141, loss 326.48040866851807
#    every episode report:      Episode 314 : reward -147.2755126953125, loss 324.97329807281494
#    every episode report:      Episode 315 : reward 18.406850814819336, loss 314.9937000274658
#    every episode report:      Episode 316 : reward -45.23984146118164, loss 330.67113304138184
#    every episode report:      Episode 317 : reward -70.45918273925781, loss 329.3964557647705
#    every episode report:      Episode 318 : reward 24.23313331604004, loss 302.57313537597656
#    every episode report:      Episode 319 : reward -0.9576363563537598, loss 298.7690601348877
#    every episode report:      Episode 320 : reward -114.58042907714844, loss 304.2004404067993
#    every episode report:      Episode 321 : reward -2.1788158416748047, loss 339.4543104171753
#    every episode report:      Episode 322 : reward -118.02178955078125, loss 368.5237817764282
#    every episode report:      Episode 323 : reward -140.3103790283203, loss 354.43959045410156
#    every episode report:      Episode 324 : reward 33.08705139160156, loss 346.9395408630371
#    every episode report:      Episode 325 : reward -28.098594665527344, loss 336.797251701355
#    every episode report:      Episode 326 : reward -25.859760284423828, loss 375.7756519317627
#    every episode report:      Episode 327 : reward -25.950870513916016, loss 363.69317150115967
#    every episode report:      Episode 328 : reward 17.859943389892578, loss 338.6913061141968
#    every episode report:      Episode 329 : reward 21.635238647460938, loss 315.07862663269043
#    every episode report:      Episode 330 : reward 50.28767776489258, loss 318.5920171737671
#    every episode report:      Episode 331 : reward -27.429628372192383, loss 329.94164848327637
#    every episode report:      Episode 332 : reward -5.7081298828125, loss 316.9258508682251
#    every episode report:      Episode 333 : reward -92.87254333496094, loss 318.56901931762695
#    every episode report:      Episode 334 : reward -193.86228942871094, loss 360.67437076568604
#    every episode report:      Episode 335 : reward -0.7781723737716675, loss 359.01169872283936
#    every episode report:      Episode 336 : reward -68.65863037109375, loss 352.4548873901367
#    every episode report:      Episode 337 : reward -5.686882495880127, loss 351.6689348220825
#    every episode report:      Episode 338 : reward -5.802824020385742, loss 354.4965019226074
#    every episode report:      Episode 339 : reward -115.85197448730469, loss 360.60791969299316
#    every episode report:      Episode 340 : reward 20.898359298706055, loss 363.072039604187
#    every episode report:      Episode 341 : reward 16.515758514404297, loss 377.11000633239746
#    every episode report:      Episode 342 : reward -24.781084060668945, loss 368.25416564941406
#    every episode report:      Episode 343 : reward -19.982847213745117, loss 348.76370906829834
#    every episode report:      Episode 344 : reward 16.632766723632812, loss 337.95718479156494
#    every episode report:      Episode 345 : reward 18.608797073364258, loss 329.9899206161499
#    every episode report:      Episode 346 : reward 10.757585525512695, loss 350.00998306274414
#    every episode report:      Episode 347 : reward 42.50389099121094, loss 338.6824359893799
#    every episode report:      Episode 348 : reward 8.575675964355469, loss 336.3359317779541
#    every episode report:      Episode 349 : reward -29.61823081970215, loss 323.7602701187134
#    every episode report:      Episode 350 : reward -53.90413284301758, loss 321.57885456085205
# Episode 350 : train_reward -24.98453666482653, train_loss 337.52379230577117
# Episode 350 : eval_reward -21.509376525878906, eval_loss 345.48838996887207
#    every episode report:      Episode 351 : reward 16.648513793945312, loss 340.8564329147339
#    every episode report:      Episode 352 : reward 8.519689559936523, loss 332.6250114440918
#    every episode report:      Episode 353 : reward -22.479005813598633, loss 334.4029016494751
#    every episode report:      Episode 354 : reward -31.303983688354492, loss 337.05516052246094
#    every episode report:      Episode 355 : reward -63.67192077636719, loss 329.528582572937
#    every episode report:      Episode 356 : reward 0.49855804443359375, loss 359.16549015045166
#    every episode report:      Episode 357 : reward -3.2646961212158203, loss 342.4418306350708
#    every episode report:      Episode 358 : reward -40.3759651184082, loss 332.76830673217773
#    every episode report:      Episode 359 : reward -84.20160675048828, loss 339.77128314971924
#    every episode report:      Episode 360 : reward 18.290180206298828, loss 328.10173892974854
#    every episode report:      Episode 361 : reward -119.20523071289062, loss 360.7382764816284
#    every episode report:      Episode 362 : reward -100.57830810546875, loss 352.73157501220703
#    every episode report:      Episode 363 : reward 28.343074798583984, loss 331.2098197937012
#    every episode report:      Episode 364 : reward -54.447994232177734, loss 331.7542667388916
#    every episode report:      Episode 365 : reward -8.924991607666016, loss 322.3053159713745
#    every episode report:      Episode 366 : reward -15.474838256835938, loss 355.86774253845215
#    every episode report:      Episode 367 : reward -8.870645523071289, loss 328.29602909088135
#    every episode report:      Episode 368 : reward -2.583698272705078, loss 335.9227247238159
#    every episode report:      Episode 369 : reward 16.827014923095703, loss 341.773681640625
#    every episode report:      Episode 370 : reward -111.88737487792969, loss 343.55375576019287
#    every episode report:      Episode 371 : reward 2.3712158203125, loss 377.059419631958
#    every episode report:      Episode 372 : reward 36.487548828125, loss 367.47261238098145
#    every episode report:      Episode 373 : reward 22.77435302734375, loss 361.07922172546387
#    every episode report:      Episode 374 : reward -0.07612085342407227, loss 349.03744888305664
#    every episode report:      Episode 375 : reward -11.404304504394531, loss 334.47325229644775
#    every episode report:      Episode 376 : reward -196.26675415039062, loss 358.2974605560303
#    every episode report:      Episode 377 : reward -63.15800094604492, loss 357.903039932251
#    every episode report:      Episode 378 : reward -100.27098846435547, loss 357.16068267822266
#    every episode report:      Episode 379 : reward -43.50246047973633, loss 338.2782506942749
#    every episode report:      Episode 380 : reward -76.32554626464844, loss 346.72412395477295
#    every episode report:      Episode 381 : reward -72.35530090332031, loss 388.3497009277344
#    every episode report:      Episode 382 : reward -68.1771240234375, loss 371.48408699035645
#    every episode report:      Episode 383 : reward 1.6616642475128174, loss 349.96113300323486
#    every episode report:      Episode 384 : reward -68.46959686279297, loss 352.28526878356934
#    every episode report:      Episode 385 : reward -10.749737739562988, loss 356.17436504364014
#    every episode report:      Episode 386 : reward 30.669185638427734, loss 446.8729057312012
#    every episode report:      Episode 387 : reward -174.86679077148438, loss 432.85345554351807
#    every episode report:      Episode 388 : reward 6.384210586547852, loss 438.258505821228
#    every episode report:      Episode 389 : reward -25.3049373626709, loss 413.4258871078491
#    every episode report:      Episode 390 : reward -19.836389541625977, loss 407.22033309936523
#    every episode report:      Episode 391 : reward 2.356907844543457, loss 444.52163219451904
#    every episode report:      Episode 392 : reward -123.65309143066406, loss 480.6443395614624
#    every episode report:      Episode 393 : reward -86.09818267822266, loss 459.4456624984741
#    every episode report:      Episode 394 : reward -28.28278160095215, loss 413.840633392334
#    every episode report:      Episode 395 : reward 38.9893913269043, loss 412.14370822906494
#    every episode report:      Episode 396 : reward -60.94223403930664, loss 404.74227809906006
#    every episode report:      Episode 397 : reward -4.914229393005371, loss 431.1913537979126
#    every episode report:      Episode 398 : reward -3.716247320175171, loss 418.065279006958
#    every episode report:      Episode 399 : reward 10.122478485107422, loss 380.0753059387207
#    every episode report:      Episode 400 : reward -78.0051040649414, loss 390.93070697784424
# Episode 400 : train_reward -33.97341004196478, train_loss 369.99818926441424
# Episode 400 : eval_reward 50.74409103393555, eval_loss 429.5049238204956
#    every episode report:      Episode 401 : reward -1.4988656044006348, loss 423.47359466552734
#    every episode report:      Episode 402 : reward 29.711977005004883, loss 434.8550157546997
#    every episode report:      Episode 403 : reward -85.16712951660156, loss 411.6013126373291
#    every episode report:      Episode 404 : reward -67.04527282714844, loss 420.1534595489502
#    every episode report:      Episode 405 : reward 9.220365524291992, loss 415.63419818878174
#    every episode report:      Episode 406 : reward 19.53545379638672, loss 402.9413232803345
#    every episode report:      Episode 407 : reward -70.82522583007812, loss 439.08570289611816
#    every episode report:      Episode 408 : reward 37.9364128112793, loss 449.13626289367676
#    every episode report:      Episode 409 : reward 44.889732360839844, loss 405.79149532318115
#    every episode report:      Episode 410 : reward -1.014207363128662, loss 379.2393388748169
#    every episode report:      Episode 411 : reward -0.07670164108276367, loss 389.4650249481201
#    every episode report:      Episode 412 : reward -45.213409423828125, loss 372.82285499572754
#    every episode report:      Episode 413 : reward 31.47039031982422, loss 372.2660427093506
#    every episode report:      Episode 414 : reward 28.764293670654297, loss 359.3555212020874
#    every episode report:      Episode 415 : reward 21.519893646240234, loss 365.29564476013184
#    every episode report:      Episode 416 : reward -11.505622863769531, loss 381.02957344055176
#    every episode report:      Episode 417 : reward -67.11277770996094, loss 358.1927824020386
#    every episode report:      Episode 418 : reward -49.9219970703125, loss 351.18841457366943
#    every episode report:      Episode 419 : reward 22.26361083984375, loss 345.9214277267456
#    every episode report:      Episode 420 : reward 44.129180908203125, loss 350.78385066986084
#    every episode report:      Episode 421 : reward 43.261268615722656, loss 394.21582984924316
#    every episode report:      Episode 422 : reward -57.25025177001953, loss 354.34480476379395
#    every episode report:      Episode 423 : reward -4.580577850341797, loss 346.0025997161865
#    every episode report:      Episode 424 : reward 9.930463790893555, loss 351.05872917175293
#    every episode report:      Episode 425 : reward 34.707332611083984, loss 340.54498958587646
#    every episode report:      Episode 426 : reward -19.891386032104492, loss 332.56079864501953
#    every episode report:      Episode 427 : reward 28.651512145996094, loss 339.5966863632202
#    every episode report:      Episode 428 : reward 33.23484802246094, loss 371.66433811187744
#    every episode report:      Episode 429 : reward 4.971922397613525, loss 378.22981357574463
#    every episode report:      Episode 430 : reward 0.4508943557739258, loss 348.4782609939575
#    every episode report:      Episode 431 : reward -61.848655700683594, loss 371.69853115081787
#    every episode report:      Episode 432 : reward 29.363956451416016, loss 351.3903341293335
#    every episode report:      Episode 433 : reward -67.37543487548828, loss 353.3576908111572
#    every episode report:      Episode 434 : reward -12.132098197937012, loss 344.9095916748047
#    every episode report:      Episode 435 : reward -141.8585968017578, loss 342.86827087402344
#    every episode report:      Episode 436 : reward 13.469414710998535, loss 342.9178991317749
#    every episode report:      Episode 437 : reward -39.973636627197266, loss 332.0900640487671
#    every episode report:      Episode 438 : reward -27.175310134887695, loss 344.3354949951172
#    every episode report:      Episode 439 : reward 8.78553581237793, loss 317.9462671279907
#    every episode report:      Episode 440 : reward 17.292097091674805, loss 319.26497173309326
#    every episode report:      Episode 441 : reward 3.3038840293884277, loss 322.87799549102783
#    every episode report:      Episode 442 : reward 19.025968551635742, loss 324.14177894592285
#    every episode report:      Episode 443 : reward -33.58679962158203, loss 329.5647373199463
#    every episode report:      Episode 444 : reward -14.144784927368164, loss 322.28527545928955
#    every episode report:      Episode 445 : reward 16.343015670776367, loss 332.8085470199585
#    every episode report:      Episode 446 : reward 10.068192481994629, loss 337.0855026245117
#    every episode report:      Episode 447 : reward -4.856622219085693, loss 325.18968391418457
#    every episode report:      Episode 448 : reward -87.69861602783203, loss 325.26831817626953
#    every episode report:      Episode 449 : reward -14.110468864440918, loss 321.8890657424927
#    every episode report:      Episode 450 : reward 1.5280466079711914, loss 319.19558334350586
# Episode 450 : train_reward -8.644139426095146, train_loss 362.1799941354868
# Episode 450 : eval_reward 45.594696044921875, eval_loss 319.20736503601074
#    every episode report:      Episode 451 : reward 13.12429141998291, loss 342.3558931350708
#    every episode report:      Episode 452 : reward 38.100921630859375, loss 368.8631772994995
#    every episode report:      Episode 453 : reward 8.974702835083008, loss 348.70750999450684
#    every episode report:      Episode 454 : reward -100.27503967285156, loss 343.1208086013794
#    every episode report:      Episode 455 : reward 40.460166931152344, loss 367.54358100891113
#    every episode report:      Episode 456 : reward -67.85893249511719, loss 394.4951448440552
#    every episode report:      Episode 457 : reward -3.8187665939331055, loss 400.3420162200928
#    every episode report:      Episode 458 : reward 16.686538696289062, loss 355.19111347198486
#    every episode report:      Episode 459 : reward -30.75760269165039, loss 370.79913425445557
#    every episode report:      Episode 460 : reward -82.82315063476562, loss 343.4813356399536
#    every episode report:      Episode 461 : reward 37.92449188232422, loss 337.23774909973145
#    every episode report:      Episode 462 : reward 46.055091857910156, loss 330.9937582015991
#    every episode report:      Episode 463 : reward -10.15795612335205, loss 324.9767894744873
#    every episode report:      Episode 464 : reward -9.498320579528809, loss 330.56912422180176
#    every episode report:      Episode 465 : reward 7.453723430633545, loss 325.31500816345215
#    every episode report:      Episode 466 : reward -65.2099838256836, loss 337.5480308532715
#    every episode report:      Episode 467 : reward -12.429793357849121, loss 323.34336376190186
#    every episode report:      Episode 468 : reward -36.944435119628906, loss 332.9868507385254
#    every episode report:      Episode 469 : reward -19.809215545654297, loss 320.64148330688477
#    every episode report:      Episode 470 : reward 4.065938949584961, loss 330.0901708602905
#    every episode report:      Episode 471 : reward -28.42507553100586, loss 334.75774478912354
#    every episode report:      Episode 472 : reward 53.387718200683594, loss 335.38011932373047
#    every episode report:      Episode 473 : reward 26.599096298217773, loss 324.8502426147461
#    every episode report:      Episode 474 : reward 35.287635803222656, loss 313.9433469772339
#    every episode report:      Episode 475 : reward -277.2460021972656, loss 432.88531970977783
#    every episode report:      Episode 476 : reward 11.838262557983398, loss 438.30214500427246
#    every episode report:      Episode 477 : reward -8.660648345947266, loss 414.5681219100952
#    every episode report:      Episode 478 : reward 6.052457332611084, loss 382.3453712463379
#    every episode report:      Episode 479 : reward -159.36669921875, loss 362.2855415344238
#    every episode report:      Episode 480 : reward 12.602685928344727, loss 409.9955129623413
#    every episode report:      Episode 481 : reward -56.60532760620117, loss 371.5856876373291
#    every episode report:      Episode 482 : reward -106.56556701660156, loss 383.832200050354
#    every episode report:      Episode 483 : reward -54.02284240722656, loss 355.6988697052002
#    every episode report:      Episode 484 : reward 35.663482666015625, loss 356.60106658935547
#    every episode report:      Episode 485 : reward 1.1773524284362793, loss 361.64036655426025
#    every episode report:      Episode 486 : reward -52.50651168823242, loss 407.69035816192627
#    every episode report:      Episode 487 : reward 14.063867568969727, loss 398.87945556640625
#    every episode report:      Episode 488 : reward -39.69248962402344, loss 358.5550479888916
#    every episode report:      Episode 489 : reward -191.95787048339844, loss 382.5377149581909
#    every episode report:      Episode 490 : reward -90.99950408935547, loss 389.00533390045166
#    every episode report:      Episode 491 : reward -102.30817413330078, loss 395.9112272262573
#    every episode report:      Episode 492 : reward -10.715937614440918, loss 398.14831733703613
#    every episode report:      Episode 493 : reward -88.14967346191406, loss 381.9237003326416
#    every episode report:      Episode 494 : reward -118.76947021484375, loss 377.31372928619385
#    every episode report:      Episode 495 : reward -12.570531845092773, loss 394.51373958587646
#    every episode report:      Episode 496 : reward -17.185304641723633, loss 387.58598232269287
#    every episode report:      Episode 497 : reward 30.562034606933594, loss 396.47592639923096
#    every episode report:      Episode 498 : reward 45.899322509765625, loss 376.5523729324341
#    every episode report:      Episode 499 : reward -30.38011932373047, loss 380.8868188858032
#    every episode report:      Episode 500 : reward 53.16672134399414, loss 373.36329555511475
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_62372\3659015225.py in <module>
# ----> 1 train_Q4()
#
# ~\AppData\Local\Temp\ipykernel_62372\4037159447.py in train_Q4()
#      72             DQNagent_m.update_target_model()
#      73         if i % 50 == 0 :
# ---> 74             tuple_list = np.array([eval_one(env_m,DQNagent_m,i) for m in range(20)])
#      75             eval_losss = np.mean(tuple_list,axis = 0)[1]
#      76             eval_rewards = np.mean(tuple_list,axis = 0)[0]
#
# ~\AppData\Local\Temp\ipykernel_62372\4037159447.py in <listcomp>(.0)
#      72             DQNagent_m.update_target_model()
#      73         if i % 50 == 0 :
# ---> 74             tuple_list = np.array([eval_one(env_m,DQNagent_m,i) for m in range(20)])
#      75             eval_losss = np.mean(tuple_list,axis = 0)[1]
#      76             eval_rewards = np.mean(tuple_list,axis = 0)[0]
#
# ~\AppData\Local\Temp\ipykernel_62372\4037159447.py in eval_one(env, agent, random_seed)
#      39
#      40 def eval_one(env,agent, random_seed):
# ---> 41     state, _ = env.reset(random_seed)
#      42     done = False
#      43     total_reward = 0
#
# c:\ANN\repo\DQN\Miniproject_DQN\epidemic_env\env.py in reset(self, seed)
#     246
#     247         _obs = self.dyn.step() # This obs is Obs class
# --> 248         self.last_obs = self.get_obs(_obs) # This obs might be tensorized
#     249         self.last_info = self._get_info()
#     250         return self.last_obs, self.last_info
#
# c:\ANN\repo\DQN\Miniproject_DQN\epidemic_env\env.py in get_obs(self, obs)
#     169             torch.Tensor: the observation tensor.
#     170         """
# --> 171         return self.observation_preprocessor(obs,self.dyn)
#     172
#     173     def _parse_action(self, a):
#
# ~\AppData\Local\Temp\ipykernel_62372\4121021570.py in observation_preprocessor_m(obs, dyn)
#      36 def observation_preprocessor_m(obs: Observation, dyn:ModelDynamics):
#      37     infected = SCALE * np.power(np.array([np.array(obs.city[c].infected)/obs.pop[c] for c in dyn.cities]), 0.25)
# ---> 38     dead = SCALE * np.power( np.array([np.array(obs.city[c].dead)/obs.pop[c] for c in dyn.cities]), 0.25)
#      39     confined = np.ones_like(dead)*int((dyn.get_action()['confinement']))
#      40     isolationed = np.ones_like(dead)*int((dyn.get_action()['isolation']))
#
# KeyboardInterrupt:

# %%
def plot_pic(log):
    """ Parse the logs """
    total = {p:np.array([getattr(l.total,p) for l in log]) for p in dyn.parameters}
    cities = {c:{p:np.array([getattr(l.city[c],p) for l in log]) for p in dyn.parameters} for c in dyn.cities}
    actions = {a:np.array([l.action[a] for l in log]) for a in log[0].action.keys()}

    from matplotlib.ticker import MultipleLocator
    fig = plt.figure(figsize=(14,10))
    ax_leftstate = plt.subplot2grid(shape=(9, 2), loc=(0, 0), rowspan=4)
    ax_leftobs = plt.subplot2grid(shape=(9, 2), loc=(4, 0), rowspan=3)
    ax_leftactions = plt.subplot2grid(shape=(9, 2), loc=(7, 0), rowspan=2)
    ax_right = [plt.subplot2grid(shape=(9, 2), loc=(0, 1), colspan=1)]
    ax_right += [plt.subplot2grid(shape=(9, 2), loc=(i, 1), colspan=1) for i in range(1,9)]
    ax_right = {k:ax_right[_id] for _id,k in enumerate(cities.keys())}

    [ax_leftstate.plot(y) for y in total.values()]
    ax_leftstate.legend(total.keys())
    ax_leftstate.set_title('Full state')
    ax_leftstate.set_ylabel('number of people in each state')

    [ax_leftobs.plot(total[y]) for y in ['infected','dead']]
    ax_leftobs.legend(['infected','dead'])
    ax_leftobs.set_title('Observable state')
    ax_leftobs.set_ylabel('number of people in each state')

    ax_leftactions.imshow(np.array([v for v in actions.values()]).astype(np.uint8),aspect='auto')
    ax_leftactions.set_title('Actions')
    ax_leftactions.set_yticks([0,1,2,3])
    ax_leftactions.set_yticklabels(list(actions.keys()))
    ax_leftactions.set_xlabel('time (in weeks)')

    [ax.plot(cities[c]['infected']) for c, ax in ax_right.items()]
    [ax.plot(cities[c]['dead']) for c, ax in ax_right.items()]
    [ax.set_ylabel(c) for c, ax in ax_right.items()]
    [ax.xaxis.set_major_locator(plt.NullLocator()) for c, ax in ax_right.items()]
    ax_right['Zürich'].set_xlabel('time (in weeks)')
    ax_right['Zürich'].xaxis.set_major_locator(MultipleLocator(2.000))

    fig.tight_layout()
    plt.show()

# %%
testagent = DQN_Agent(env_m, epsilon=0.7, batch_size=BATCH_SIZE, buffer_size=20000, GAMMA=GAMMA,lr = LR, device=device ,
                    policy_net=policy_net_m, target_net=target_net_m)
#testagent.load_model("DQN_best_Q4.pth")
log2 = []
finished = False
obs, info = env_m.reset(0)

while not finished:
    action = testagent.act(obs,0.4)
    obs, R, finished, info = env_m.step(action)
    log2.append(info) # save the information dict for logging
    if finished:
        break

plot_pic(log2)

# %%
one_episode_decay(env_m,DQNagent_m,1,0.7,0.2,500,450)
# Out:
# (-120.44697570800781, 6844.538772583008)

# %%
def dqn_plot(env, agent):
    deaths_list, rewards_list, conf_days = [],[],[]
    seeds = range(20)
    for i in range(20):
        total_deaths = 0
        total_rewards = 0
        total_conf = 0
        
        finished = False
        obs, info = env.reset(seeds[i])

  
        while not finished:
            action = agent.act(obs,0)
            #print(action.item())
            #if action.item() == 1: total_conf += 1
            obs, R, finished, info = env.step(action)
            
            total_rewards += float(R)
            if finished:
                deaths_list.append(info.total.dead)
                break
        
        conf_days.append(total_conf)
        rewards_list.append(total_rewards)

    return deaths_list, rewards_list, conf_days

# %%
deaths, rewards, conf_days  = dqn_plot(env_m, DQNagent_m)

fig, ax = plt.subplots(3,1,figsize=(18,8))
def hist_avg(ax, data,title):
    ymax = 50
    if title == 'deaths':
        x_range = (0,200000)
    elif title == 'cumulative rewards': 
        x_range = (-300,300)
    elif 'days' in title:
        x_range = (0,200)
    else:
        raise ValueError(f'{title} is not a valid title') 
    ax.set_title(title)
    ax.set_ylim(0,ymax)
    ax.vlines([np.mean(data)],0,ymax,color='red')
    ax.hist(data,bins=60,range=x_range)
    
hist_avg(ax[0], deaths,'deaths')
hist_avg(ax[1], rewards,'cumulative rewards')
hist_avg(ax[2], conf_days,'confined days')

fig.tight_layout()
plt.show()

""" Print example """
print(f'Average death number: {np.mean(deaths)}')
print(f'Average number of confined days: {np.mean(conf_days)}')
print(f'Average cumulative reward: {np.mean(rewards)}')
